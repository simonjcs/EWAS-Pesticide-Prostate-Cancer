# %%
import pandas as pd
import glob
import os
from tqdm.notebook import tqdm


results_paths = glob.glob("results/results_*/raw")
results_paths
# Out:
# ['results/results_ICPSR_1992_EPEST_2003/raw',
#  'results/results_ICPSR_1992_EPEST_2002/raw',
#  'results/results_ICPSR_1992_EPEST_1997/raw',
#  'results/results_ICPSR_1992_EPEST_2001/raw']

# %%
def combine_metrics_to_csv(folder_path, save_path):
    # Use glob to get all files matching the pattern
    files = glob.glob(os.path.join(folder_path, "*_metrics.json"))
    # print(files)

    # List to hold individual DataFrames
    dfs = []

    # Process each file
    for file in tqdm(files):
        # Extract the filename without extension
        base_name = os.path.basename(file).replace("_metrics.json", "")

        # Split the filename into pesticide and model_type
        pesticide, model_type = base_name.rsplit("_", 1)

        # Load the JSON data into a DataFrame
        df = pd.read_json(file, typ="series").to_frame().T
        df["pesticide"] = pesticide
        df["model_type"] = model_type

        # Append the DataFrame to dfs list
        dfs.append(df)

    # Concatenate all DataFrames
    final_df = pd.concat(dfs, ignore_index=True)

    # Rearrange columns
    final_df = final_df[["pesticide",
                         "model_type", "mse", "rmse", "mae", "r2"]]
    final_df = final_df.sort_values(by=["pesticide", "model_type"])

    # Write to CSV

    final_df.to_csv(os.path.join(save_path, "metrics.csv"), index=False)


# Usage
print(f"Combining metrics from {len(results_paths)} folders...")
for folder_path in tqdm(results_paths):
    save_path = os.path.dirname(folder_path)
    print(save_path)

    os.makedirs(save_path, exist_ok=True)

    combine_metrics_to_csv(folder_path, save_path)
# Out:
# Combining metrics from 4 folders...
#   0%|          | 0/4 [00:00<?, ?it/s]
# results/results_ICPSR_1992_EPEST_2003
#   0%|          | 0/321 [00:00<?, ?it/s]
# results/results_ICPSR_1992_EPEST_2002
#   0%|          | 0/320 [00:00<?, ?it/s]
# results/results_ICPSR_1992_EPEST_1997
#   0%|          | 0/295 [00:00<?, ?it/s]
# results/results_ICPSR_1992_EPEST_2001
#   0%|          | 0/314 [00:00<?, ?it/s]

# %%
from pprint import pprint
import pandas as pd
import os
import glob


def get_files_with_prefix(folder_path, prefix_pattern):
    """Return a list of files matching the prefix pattern."""
    return glob.glob(os.path.join(folder_path, prefix_pattern))


def group_files_by_prefix(files):
    """Groups files by their shared prefix."""
    grouped_files = {}
    for file in files:
        prefix = "_".join(os.path.basename(file).split("_")[:1])
        if prefix not in grouped_files:
            grouped_files[prefix] = []
        grouped_files[prefix].append(file)
    # print(grouped_files)
    return grouped_files


def merge_multiple_files_on_index(files):
    """Merge multiple files on the index and return the merged DataFrame."""
    # Start with the first file
    # print(files)

    cols = get_cols(files)

    merged_df = pd.read_csv(files[0])

    # Merge remaining files one by one
    # display(merged_df)
    for file in files[1:]:
        df = pd.read_csv(file).drop(columns=["feature_name"])
        # display(df)
        merged_df = pd.merge(merged_df, df, how="outer", on="feature_code")
        # display(merged_df)
    merged_df.columns = cols

    return merged_df


def get_cols(files):
    cols = ["feature_code", "feature_name"]
    for f_ in files:
        filename = os.path.basename(f_)
        col_name = ""
        if "_xgboost" in filename:
            col_name += "XGBoost"
        elif "_rf" in filename:
            col_name += "RF"
        if "_permute" in filename:
            col_name += " importance (permute)"
        elif "_mdi" in filename:
            col_name += " importance (MDI)"
        else:
            cols_to_add = [" p-value (permute)", " std (permute)"]
            cols_to_add = [col_name + col for col in cols_to_add]
            cols += cols_to_add
            continue
        cols.append(col_name)
    # print(f"Getting cols: {cols}")
    return cols


def merge_matching_files(folder_path, prefix, save_path):
    files = get_files_with_prefix(folder_path, f"{prefix}_*.csv")
    grouped_files = group_files_by_prefix(files)
    print(f"Found {len(grouped_files)} groups of files with prefix {prefix}.")

    for prefix, file_group in grouped_files.items():
        if len(file_group) < 2:
            print(f"Skipping {prefix}, found only {len(file_group)} file(s).")
            continue

        merged_df = merge_multiple_files_on_index(file_group)
        merged_df.set_index("feature_code", inplace=True)

        merged_df = merged_df.sort_index(axis=1)
        save_path = os.path.join(save_path, f"{prefix}_merged.csv")
        merged_df.to_csv(save_path)
        # print(f"Merged {prefix} files into {save_path}")


def get_all_prefixes(files):
    """Return all unique prefixes from a list of files."""
    prefixes = set()

    for file in files:
        prefix = "_".join(os.path.basename(file).split("_")[:1])
        prefixes.add(prefix)

    return list(prefixes)

# %%
for folder_path in tqdm(results_paths):
    glob_pattern = os.path.join(folder_path, "*.csv")

    files = glob.glob(glob_pattern)
    unique_prefixes = get_all_prefixes(files)

    save_path = os.path.dirname(folder_path)

    #
    print(f"Found {len(unique_prefixes)} unique prefixes in {folder_path}")
    print(f"Saving to {save_path}")
    for prefix in tqdm(unique_prefixes, desc="Merging files"):
        merge_matching_files(folder_path, prefix, save_path)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# Found 321 unique prefixes in results/results_ICPSR_1992_EPEST_2003/raw
# Saving to results/results_ICPSR_1992_EPEST_2003
# Merging files:   0%|          | 0/321 [00:00<?, ?it/s]
# Found 1 groups of files with prefix Chloropicrin.
# Found 1 groups of files with prefix Zeta-Cypermethrin.
# Found 1 groups of files with prefix Clodinafop.
# Found 1 groups of files with prefix Butralin.
# Found 1 groups of files with prefix Pelargonic Acid.
# Found 1 groups of files with prefix Maneb.
# Found 1 groups of files with prefix Pyridaben.
# Found 1 groups of files with prefix Diquat.
# Found 1 groups of files with prefix Pyraflufen Ethyl.
# Found 1 groups of files with prefix Iodosulfuron.
# Found 1 groups of files with prefix Metam.
# Found 1 groups of files with prefix Atrazine.
# Found 1 groups of files with prefix Thiodicarb.
# Found 1 groups of files with prefix Hexythiazox.
# Found 1 groups of files with prefix Bacillus Subtilis.
# Found 1 groups of files with prefix Thiram.
# Found 1 groups of files with prefix Etridiazole.
# Found 1 groups of files with prefix Imazapic.
# Found 1 groups of files with prefix Potassium Oleate.
# Found 1 groups of files with prefix Myclobutanil.
# Found 1 groups of files with prefix Mefenoxam.
# Found 1 groups of files with prefix Acequinocyl.
# Found 1 groups of files with prefix Tralomethrin.
# Found 1 groups of files with prefix Mcpb.
# Found 1 groups of files with prefix Prothioconazole.
# Found 1 groups of files with prefix Sodium Chlorate.
# Found 1 groups of files with prefix Diclofop.
# Found 1 groups of files with prefix Fenamidone.
# Found 1 groups of files with prefix Phorate.
# Found 1 groups of files with prefix Terbufos.
# Found 1 groups of files with prefix Fatty Alcohols.
# Found 1 groups of files with prefix Acifluorfen.
# Found 1 groups of files with prefix Dicloran.
# Found 1 groups of files with prefix Flufenacet.
# Found 1 groups of files with prefix Metalaxyl.
# Found 1 groups of files with prefix 2,4-D.
# Found 1 groups of files with prefix Chloroneb.
# Found 1 groups of files with prefix Quinclorac.
# Found 1 groups of files with prefix Cryolite.
# Found 1 groups of files with prefix Buprofezin.
# Found 1 groups of files with prefix Dimethipin.
# Found 1 groups of files with prefix Bispyribac.
# Found 1 groups of files with prefix Cyromazine.
# Found 1 groups of files with prefix Metaldehyde.
# Found 1 groups of files with prefix Methoxyfenozide.
# Found 1 groups of files with prefix Fenamiphos.
# Found 1 groups of files with prefix Flumetsulam.
# Found 1 groups of files with prefix Potassium Bicarbonate.
# Found 1 groups of files with prefix Triadimefon.
# Found 1 groups of files with prefix Fenpropathrin.
# Found 1 groups of files with prefix Dimethenamid-P.
# Found 1 groups of files with prefix Naled.
# Found 1 groups of files with prefix Fosetyl.
# Found 1 groups of files with prefix Chlorsulfuron.
# Found 1 groups of files with prefix Dodine.
# Found 1 groups of files with prefix Cyanazine.
# Found 1 groups of files with prefix Sulfosulfuron.
# Found 1 groups of files with prefix Difenzoquat.
# Found 1 groups of files with prefix Cypermethrin.
# Found 1 groups of files with prefix Tebufenozide.
# Found 1 groups of files with prefix Rimsulfuron.
# Found 1 groups of files with prefix Propoxycarbazone.
# Found 1 groups of files with prefix Thiamethoxam.
# Found 1 groups of files with prefix Acetochlor.
# Found 1 groups of files with prefix Flumioxazin.
# Found 1 groups of files with prefix Pyraclostrobin.
# Found 1 groups of files with prefix Sulfuric Acid.
# Found 1 groups of files with prefix Dicrotophos.
# Found 1 groups of files with prefix Piperonyl Butoxide.
# Found 1 groups of files with prefix Halosulfuron.
# Found 1 groups of files with prefix Phosmet.
# Found 1 groups of files with prefix Carfentrazone-Ethyl.
# Found 1 groups of files with prefix Fenarimol.
# Found 1 groups of files with prefix Cyhalothrin-Lambda.
# Found 1 groups of files with prefix Pymetrozine.
# Found 1 groups of files with prefix Oxydemeton-Methyl.
# Found 1 groups of files with prefix Tribufos.
# Found 1 groups of files with prefix Cuprous Oxide.
# Found 1 groups of files with prefix Benfluralin.
# Found 1 groups of files with prefix Metconazole.
# Found 1 groups of files with prefix Tetraconazole.
# Found 1 groups of files with prefix Thiazopyr.
# Found 1 groups of files with prefix Clomazone.
# Found 1 groups of files with prefix Chlorothalonil.
# Found 1 groups of files with prefix Bifenazate.
# Found 1 groups of files with prefix Rotenone.
# Found 1 groups of files with prefix Hexazinone.
# Found 1 groups of files with prefix Orthosulfamuron.
# Found 1 groups of files with prefix Metribuzin.
# Found 1 groups of files with prefix Gibberellic Acid.
# Found 1 groups of files with prefix Trifloxysulfuron.
# Found 1 groups of files with prefix Flumetralin.
# Found 1 groups of files with prefix Bromoxynil.
# Found 1 groups of files with prefix Prosulfuron.
# Found 1 groups of files with prefix Copper Oxychloride S.
# Found 1 groups of files with prefix Fluazifop.
# Found 1 groups of files with prefix Bentazone.
# Found 1 groups of files with prefix Bordeaux Mixture.
# Found 1 groups of files with prefix Emamectin.
# Found 1 groups of files with prefix Propyzamide.
# Found 1 groups of files with prefix Flutolanil.
# Found 1 groups of files with prefix Terbacil.
# Found 1 groups of files with prefix Propargite.
# Found 1 groups of files with prefix Fenhexamid.
# Found 1 groups of files with prefix Propazine.
# Found 1 groups of files with prefix Captan.
# Found 1 groups of files with prefix Ethephon.
# Found 1 groups of files with prefix Bacillus Pumilis.
# Found 1 groups of files with prefix Spirodiclofen.
# Found 1 groups of files with prefix Imazaquin.
# Found 1 groups of files with prefix Kaolin Clay.
# Found 1 groups of files with prefix Fipronil.
# Found 1 groups of files with prefix Imazapyr.
# Found 1 groups of files with prefix Ethalfluralin.
# Found 1 groups of files with prefix Trifluralin.
# Found 1 groups of files with prefix Aluminum Phosphide.
# Found 1 groups of files with prefix Decan-1-Ol.
# Found 1 groups of files with prefix Pinoxaden.
# Found 1 groups of files with prefix Flucarbazone.
# Found 1 groups of files with prefix Fluometuron.
# Found 1 groups of files with prefix Foramsulfuron.
# Found 1 groups of files with prefix Napropamide.
# Found 1 groups of files with prefix Oryzalin.
# Found 1 groups of files with prefix Thiacloprid.
# Found 1 groups of files with prefix Acetamiprid.
# Found 1 groups of files with prefix Pyriproxyfen.
# Found 1 groups of files with prefix Abamectin.
# Found 1 groups of files with prefix Cydia Pomonella.
# Found 1 groups of files with prefix Quinoxyfen.
# Found 1 groups of files with prefix Aminopyralid.
# Found 1 groups of files with prefix Azinphos-Methyl.
# Found 1 groups of files with prefix Naphthylacetamide.
# Found 1 groups of files with prefix Thidiazuron.
# Found 1 groups of files with prefix Glyphosate.
# Found 1 groups of files with prefix Kresoxim-Methyl.
# Found 1 groups of files with prefix Vinclozolin.
# Found 1 groups of files with prefix Diflufenzopyr.
# Found 1 groups of files with prefix Alachlor.
# Found 1 groups of files with prefix Pebulate.
# Found 1 groups of files with prefix Tetraborohydrate.
# Found 1 groups of files with prefix Metsulfuron.
# Found 1 groups of files with prefix Sethoxydim.
# Found 1 groups of files with prefix Picloram.
# Found 1 groups of files with prefix Triclopyr.
# Found 1 groups of files with prefix Hydrogen Peroxide.
# Found 1 groups of files with prefix Ethofumesate.
# Found 1 groups of files with prefix Cyhalothrin-Gamma.
# Found 1 groups of files with prefix Endosulfan.
# Found 1 groups of files with prefix Clethodim.
# Found 1 groups of files with prefix Profenofos.
# Found 1 groups of files with prefix Pyrethrins.
# Found 1 groups of files with prefix Copper Sulf Tribasic.
# Found 1 groups of files with prefix Imazamox.
# Found 1 groups of files with prefix Thiophanate-Methyl.
# Found 1 groups of files with prefix Clofentezine.
# Found 1 groups of files with prefix Primisulfuron.
# Found 1 groups of files with prefix Ametryn.
# Found 1 groups of files with prefix Dinotefuran.
# Found 1 groups of files with prefix Chlorimuron.
# Found 1 groups of files with prefix Imidacloprid.
# Found 1 groups of files with prefix Harpin Protein.
# Found 1 groups of files with prefix Lactofen.
# Found 1 groups of files with prefix Thiobencarb.
# Found 1 groups of files with prefix Metam Potassium.
# Found 1 groups of files with prefix Azadirachtin.
# Found 1 groups of files with prefix Zoxamide.
# Found 1 groups of files with prefix Lindane.
# Found 1 groups of files with prefix Tribenuron Methyl.
# Found 1 groups of files with prefix Bacillus Cereus.
# Found 1 groups of files with prefix Carbaryl.
# Found 1 groups of files with prefix Triasulfuron.
# Found 1 groups of files with prefix Methyl Bromide.
# Found 1 groups of files with prefix Quintozene.
# Found 1 groups of files with prefix Oxytetracycline.
# Found 1 groups of files with prefix Fenbutatin Oxide.
# Found 1 groups of files with prefix Dichlobenil.
# Found 1 groups of files with prefix Penoxsulam.
# Found 1 groups of files with prefix Dimethoate.
# Found 1 groups of files with prefix Cytokinin.
# Found 1 groups of files with prefix Methidathion.
# Found 1 groups of files with prefix Metolachlor-S.
# Found 1 groups of files with prefix Cyprodinil.
# Found 1 groups of files with prefix Paraquat.
# Found 1 groups of files with prefix Dichlorprop.
# Found 1 groups of files with prefix Spinosyn.
# Found 1 groups of files with prefix Naphthylacetic Acid.
# Found 1 groups of files with prefix Trifloxystrobin.
# Found 1 groups of files with prefix Disulfoton.
# Found 1 groups of files with prefix Petroleum Distillate.
# Found 1 groups of files with prefix Carbofuran.
# Found 1 groups of files with prefix Ferbam.
# Found 1 groups of files with prefix Dicofol.
# Found 1 groups of files with prefix Copper Sulfate.
# Found 1 groups of files with prefix Spiromesifen.
# Found 1 groups of files with prefix Prometon.
# Found 1 groups of files with prefix Methyl Parathion.
# Found 1 groups of files with prefix Propiconazole.
# Found 1 groups of files with prefix Chlorpyrifos.
# Found 1 groups of files with prefix Pendimethalin.
# Found 1 groups of files with prefix Msma.
# Found 1 groups of files with prefix Tri-Allate.
# Found 1 groups of files with prefix Boscalid.
# Found 1 groups of files with prefix Mancozeb.
# Found 1 groups of files with prefix Phosphoric Acid.
# Found 1 groups of files with prefix Propamocarb Hcl.
# Found 1 groups of files with prefix Clothianidin.
# Found 1 groups of files with prefix Iprodione.
# Found 1 groups of files with prefix Hydrated Lime.
# Found 1 groups of files with prefix 6-Benzyladenine.
# Found 1 groups of files with prefix Deltamethrin.
# Found 1 groups of files with prefix Etoxazole.
# Found 1 groups of files with prefix Bacillus Thuringiensis.
# Found 1 groups of files with prefix Clopyralid.
# Found 1 groups of files with prefix Acephate.
# Found 1 groups of files with prefix 2,4-Db.
# Found 1 groups of files with prefix Carboxin.
# Found 1 groups of files with prefix Diuron.
# Found 1 groups of files with prefix Cloransulam-Methyl.
# Found 1 groups of files with prefix Fluroxypyr.
# Found 1 groups of files with prefix Formetanate.
# Found 1 groups of files with prefix Nicosulfuron.
# Found 1 groups of files with prefix Isoxaflutole.
# Found 1 groups of files with prefix Fenbuconazole.
# Found 1 groups of files with prefix Glufosinate.
# Found 1 groups of files with prefix Permethrin.
# Found 1 groups of files with prefix Tralkoxydim.
# Found 1 groups of files with prefix Diazinon.
# Found 1 groups of files with prefix Mesotrione.
# Found 1 groups of files with prefix Tebupirimphos.
# Found 1 groups of files with prefix Pinolene.
# Found 1 groups of files with prefix Ziram.
# Found 1 groups of files with prefix Malathion.
# Found 1 groups of files with prefix Copper.
# Found 1 groups of files with prefix Sulfur.
# Found 1 groups of files with prefix Imazethapyr.
# Found 1 groups of files with prefix Cyazofamid.
# Found 1 groups of files with prefix Mcpa.
# Found 1 groups of files with prefix Endothal.
# Found 1 groups of files with prefix Maleic Hydrazide.
# Found 1 groups of files with prefix Cymoxanil.
# Found 1 groups of files with prefix Flumiclorac.
# Found 1 groups of files with prefix Coniothyrium Minitans.
# Found 1 groups of files with prefix Benomyl.
# Found 1 groups of files with prefix Mepiquat.
# Found 1 groups of files with prefix Chlorethoxyfos.
# Found 1 groups of files with prefix Pseudomonas Fluorescens.
# Found 1 groups of files with prefix Calcium Polysulfide.
# Found 1 groups of files with prefix Aviglycine.
# Found 1 groups of files with prefix Myrothecium Verrucaria.
# Found 1 groups of files with prefix Topramezone.
# Found 1 groups of files with prefix Linuron.
# Found 1 groups of files with prefix Eptc.
# Found 1 groups of files with prefix Triflusulfuron.
# Found 1 groups of files with prefix Fenoxaprop.
# Found 1 groups of files with prefix Sulfentrazone.
# Found 1 groups of files with prefix Flutriafol.
# Found 1 groups of files with prefix Tefluthrin.
# Found 1 groups of files with prefix Pyrimethanil.
# Found 1 groups of files with prefix Streptomycin.
# Found 1 groups of files with prefix Quizalofop.
# Found 1 groups of files with prefix Thifensulfuron.
# Found 1 groups of files with prefix Dimethomorph.
# Found 1 groups of files with prefix Fluazinam.
# Found 1 groups of files with prefix Zinc.
# Found 1 groups of files with prefix Diflubenzuron.
# Found 1 groups of files with prefix Dicamba.
# Found 1 groups of files with prefix Fentin.
# Found 1 groups of files with prefix Novaluron.
# Found 1 groups of files with prefix Famoxadone.
# Found 1 groups of files with prefix Pyrithiobac-Sodium.
# Found 1 groups of files with prefix Norflurazon.
# Found 1 groups of files with prefix Tcmtb.
# Found 1 groups of files with prefix Prohexadione.
# Found 1 groups of files with prefix Fludioxonil.
# Found 1 groups of files with prefix Metiram.
# Found 1 groups of files with prefix Cyfluthrin.
# Found 1 groups of files with prefix Bensulfuron.
# Found 1 groups of files with prefix Metolachlor.
# Found 1 groups of files with prefix Cyclanilide.
# Found 1 groups of files with prefix Tebuconazole.
# Found 1 groups of files with prefix Fomesafen.
# Found 1 groups of files with prefix Triflumizole.
# Found 1 groups of files with prefix Aldicarb.
# Found 1 groups of files with prefix Oxyfluorfen.
# Found 1 groups of files with prefix Oxamyl.
# Found 1 groups of files with prefix Desmedipham.
# Found 1 groups of files with prefix Propanil.
# Found 1 groups of files with prefix Butylate.
# Found 1 groups of files with prefix Prometryn.
# Found 1 groups of files with prefix Copper Hydroxide.
# Found 1 groups of files with prefix Isoxaben.
# Found 1 groups of files with prefix Mesosulfuron.
# Found 1 groups of files with prefix Phenmedipham.
# Found 1 groups of files with prefix Diclosulam.
# Found 1 groups of files with prefix Cycloate.
# Found 1 groups of files with prefix Acibenzolar.
# Found 1 groups of files with prefix Imazamethabenz.
# Found 1 groups of files with prefix Molinate.
# Found 1 groups of files with prefix Azoxystrobin.
# Found 1 groups of files with prefix Dichloropropene.
# Found 1 groups of files with prefix Triadimenol.
# Found 1 groups of files with prefix Methomyl.
# Found 1 groups of files with prefix Copper Oxychloride.
# Found 1 groups of files with prefix Bensulide.
# Found 1 groups of files with prefix Naptalam.
# Found 1 groups of files with prefix Flonicamid.
# Found 1 groups of files with prefix Esfenvalerate.
# Found 1 groups of files with prefix Bifenthrin.
# Found 1 groups of files with prefix Dimethenamid.
# Found 1 groups of files with prefix Cyhalofop.
# Found 1 groups of files with prefix Bromacil.
# Found 1 groups of files with prefix Fenpyroximate.
# Found 1 groups of files with prefix Tebuthiuron.
# Found 1 groups of files with prefix Neem Oil.
# Found 1 groups of files with prefix Simazine.
# Found 1 groups of files with prefix Petroleum Oil.
# Found 1 groups of files with prefix Indoxacarb.
# Found 1 groups of files with prefix Dcpa.
# Found 1 groups of files with prefix Methamidophos.
# Found 1 groups of files with prefix Ethoprophos.
# Found 1 groups of files with prefix Sulfcarbamide.
# Found 320 unique prefixes in results/results_ICPSR_1992_EPEST_2002/raw
# Saving to results/results_ICPSR_1992_EPEST_2002
# Merging files:   0%|          | 0/320 [00:00<?, ?it/s]
# Found 1 groups of files with prefix Chloropicrin.
# Found 1 groups of files with prefix Zeta-Cypermethrin.
# Found 1 groups of files with prefix Clodinafop.
# Found 1 groups of files with prefix Butralin.
# Found 1 groups of files with prefix Pelargonic Acid.
# Found 1 groups of files with prefix Maneb.
# Found 1 groups of files with prefix Pyridaben.
# Found 1 groups of files with prefix Diquat.
# Found 1 groups of files with prefix Pyraflufen Ethyl.
# Found 1 groups of files with prefix Iodosulfuron.
# Found 1 groups of files with prefix Metam.
# Found 1 groups of files with prefix Atrazine.
# Found 1 groups of files with prefix Thiodicarb.
# Found 1 groups of files with prefix Hexythiazox.
# Found 1 groups of files with prefix Bacillus Subtilis.
# Found 1 groups of files with prefix Thiram.
# Found 1 groups of files with prefix Etridiazole.
# Found 1 groups of files with prefix Imazapic.
# Found 1 groups of files with prefix Potassium Oleate.
# Found 1 groups of files with prefix Myclobutanil.
# Found 1 groups of files with prefix Mefenoxam.
# Found 1 groups of files with prefix Acequinocyl.
# Found 1 groups of files with prefix Tralomethrin.
# Found 1 groups of files with prefix Mcpb.
# Found 1 groups of files with prefix Sodium Chlorate.
# Found 1 groups of files with prefix Diclofop.
# Found 1 groups of files with prefix Fenamidone.
# Found 1 groups of files with prefix Phorate.
# Found 1 groups of files with prefix Terbufos.
# Found 1 groups of files with prefix Fatty Alcohols.
# Found 1 groups of files with prefix Acifluorfen.
# Found 1 groups of files with prefix Dicloran.
# Found 1 groups of files with prefix Flufenacet.
# Found 1 groups of files with prefix Metalaxyl.
# Found 1 groups of files with prefix 2,4-D.
# Found 1 groups of files with prefix Chloroneb.
# Found 1 groups of files with prefix Quinclorac.
# Found 1 groups of files with prefix Cryolite.
# Found 1 groups of files with prefix Buprofezin.
# Found 1 groups of files with prefix Dimethipin.
# Found 1 groups of files with prefix Bispyribac.
# Found 1 groups of files with prefix Cyromazine.
# Found 1 groups of files with prefix Metaldehyde.
# Found 1 groups of files with prefix Methoxyfenozide.
# Found 1 groups of files with prefix Fenamiphos.
# Found 1 groups of files with prefix Flumetsulam.
# Found 1 groups of files with prefix Potassium Bicarbonate.
# Found 1 groups of files with prefix Triadimefon.
# Found 1 groups of files with prefix Fenpropathrin.
# Found 1 groups of files with prefix Dimethenamid-P.
# Found 1 groups of files with prefix Naled.
# Found 1 groups of files with prefix Fosetyl.
# Found 1 groups of files with prefix Chlorsulfuron.
# Found 1 groups of files with prefix Dodine.
# Found 1 groups of files with prefix Cyanazine.
# Found 1 groups of files with prefix Sulfosulfuron.
# Found 1 groups of files with prefix Difenzoquat.
# Found 1 groups of files with prefix Cypermethrin.
# Found 1 groups of files with prefix L-Glutamic Acid.
# Found 1 groups of files with prefix Tebufenozide.
# Found 1 groups of files with prefix Rimsulfuron.
# Found 1 groups of files with prefix Propoxycarbazone.
# Found 1 groups of files with prefix Thiamethoxam.
# Found 1 groups of files with prefix Acetochlor.
# Found 1 groups of files with prefix Flumioxazin.
# Found 1 groups of files with prefix Pyraclostrobin.
# Found 1 groups of files with prefix Sulfuric Acid.
# Found 1 groups of files with prefix Dicrotophos.
# Found 1 groups of files with prefix Piperonyl Butoxide.
# Found 1 groups of files with prefix Halosulfuron.
# Found 1 groups of files with prefix Phosmet.
# Found 1 groups of files with prefix Carfentrazone-Ethyl.
# Found 1 groups of files with prefix Fenarimol.
# Found 1 groups of files with prefix Cyhalothrin-Lambda.
# Found 1 groups of files with prefix Pymetrozine.
# Found 1 groups of files with prefix Oxydemeton-Methyl.
# Found 1 groups of files with prefix Tribufos.
# Found 1 groups of files with prefix Cuprous Oxide.
# Found 1 groups of files with prefix Benfluralin.
# Found 1 groups of files with prefix Tetraconazole.
# Found 1 groups of files with prefix Thiazopyr.
# Found 1 groups of files with prefix Clomazone.
# Found 1 groups of files with prefix Chlorothalonil.
# Found 1 groups of files with prefix Bifenazate.
# Found 1 groups of files with prefix Rotenone.
# Found 1 groups of files with prefix Hexazinone.
# Found 1 groups of files with prefix Metribuzin.
# Found 1 groups of files with prefix Gibberellic Acid.
# Found 1 groups of files with prefix Trifloxysulfuron.
# Found 1 groups of files with prefix Flumetralin.
# Found 1 groups of files with prefix Bromoxynil.
# Found 1 groups of files with prefix Prosulfuron.
# Found 1 groups of files with prefix Copper Oxychloride S.
# Found 1 groups of files with prefix Fluazifop.
# Found 1 groups of files with prefix Bentazone.
# Found 1 groups of files with prefix Bordeaux Mixture.
# Found 1 groups of files with prefix Emamectin.
# Found 1 groups of files with prefix Propyzamide.
# Found 1 groups of files with prefix Flutolanil.
# Found 1 groups of files with prefix Terbacil.
# Found 1 groups of files with prefix Propargite.
# Found 1 groups of files with prefix Fenhexamid.
# Found 1 groups of files with prefix Captan.
# Found 1 groups of files with prefix Ethephon.
# Found 1 groups of files with prefix Bacillus Pumilis.
# Found 1 groups of files with prefix Spirodiclofen.
# Found 1 groups of files with prefix Imazaquin.
# Found 1 groups of files with prefix Kaolin Clay.
# Found 1 groups of files with prefix Fipronil.
# Found 1 groups of files with prefix Imazapyr.
# Found 1 groups of files with prefix Ethalfluralin.
# Found 1 groups of files with prefix Trifluralin.
# Found 1 groups of files with prefix Aluminum Phosphide.
# Found 1 groups of files with prefix Decan-1-Ol.
# Found 1 groups of files with prefix Pinoxaden.
# Found 1 groups of files with prefix Flucarbazone.
# Found 1 groups of files with prefix Fluometuron.
# Found 1 groups of files with prefix Foramsulfuron.
# Found 1 groups of files with prefix Napropamide.
# Found 1 groups of files with prefix Oryzalin.
# Found 1 groups of files with prefix Thiacloprid.
# Found 1 groups of files with prefix Acetamiprid.
# Found 1 groups of files with prefix Pyriproxyfen.
# Found 1 groups of files with prefix Abamectin.
# Found 1 groups of files with prefix Cydia Pomonella.
# Found 1 groups of files with prefix Quinoxyfen.
# Found 1 groups of files with prefix Aminopyralid.
# Found 1 groups of files with prefix Azinphos-Methyl.
# Found 1 groups of files with prefix Naphthylacetamide.
# Found 1 groups of files with prefix Thidiazuron.
# Found 1 groups of files with prefix Glyphosate.
# Found 1 groups of files with prefix Kresoxim-Methyl.
# Found 1 groups of files with prefix Vinclozolin.
# Found 1 groups of files with prefix Diflufenzopyr.
# Found 1 groups of files with prefix Alachlor.
# Found 1 groups of files with prefix Pebulate.
# Found 1 groups of files with prefix Tetraborohydrate.
# Found 1 groups of files with prefix Metsulfuron.
# Found 1 groups of files with prefix Sethoxydim.
# Found 1 groups of files with prefix Picloram.
# Found 1 groups of files with prefix Triclopyr.
# Found 1 groups of files with prefix Hydrogen Peroxide.
# Found 1 groups of files with prefix Ethofumesate.
# Found 1 groups of files with prefix Cyhalothrin-Gamma.
# Found 1 groups of files with prefix Endosulfan.
# Found 1 groups of files with prefix Clethodim.
# Found 1 groups of files with prefix Profenofos.
# Found 1 groups of files with prefix Gamma Aminobutyric Acid.
# Found 1 groups of files with prefix Pyrethrins.
# Found 1 groups of files with prefix Copper Sulf Tribasic.
# Found 1 groups of files with prefix Imazamox.
# Found 1 groups of files with prefix Thiophanate-Methyl.
# Found 1 groups of files with prefix Clofentezine.
# Found 1 groups of files with prefix Primisulfuron.
# Found 1 groups of files with prefix Ametryn.
# Found 1 groups of files with prefix Dinotefuran.
# Found 1 groups of files with prefix Chlorimuron.
# Found 1 groups of files with prefix Imidacloprid.
# Found 1 groups of files with prefix Harpin Protein.
# Found 1 groups of files with prefix Lactofen.
# Found 1 groups of files with prefix Thiobencarb.
# Found 1 groups of files with prefix Metam Potassium.
# Found 1 groups of files with prefix Azadirachtin.
# Found 1 groups of files with prefix Zoxamide.
# Found 1 groups of files with prefix Lindane.
# Found 1 groups of files with prefix Tribenuron Methyl.
# Found 1 groups of files with prefix Bacillus Cereus.
# Found 1 groups of files with prefix Carbaryl.
# Found 1 groups of files with prefix Triasulfuron.
# Found 1 groups of files with prefix Methyl Bromide.
# Found 1 groups of files with prefix Quintozene.
# Found 1 groups of files with prefix Oxytetracycline.
# Found 1 groups of files with prefix Fenbutatin Oxide.
# Found 1 groups of files with prefix Dichlobenil.
# Found 1 groups of files with prefix Penoxsulam.
# Found 1 groups of files with prefix Dimethoate.
# Found 1 groups of files with prefix Cytokinin.
# Found 1 groups of files with prefix Methidathion.
# Found 1 groups of files with prefix Metolachlor-S.
# Found 1 groups of files with prefix Cyprodinil.
# Found 1 groups of files with prefix Paraquat.
# Found 1 groups of files with prefix Dichlorprop.
# Found 1 groups of files with prefix Spinosyn.
# Found 1 groups of files with prefix Naphthylacetic Acid.
# Found 1 groups of files with prefix Trifloxystrobin.
# Found 1 groups of files with prefix Disulfoton.
# Found 1 groups of files with prefix Petroleum Distillate.
# Found 1 groups of files with prefix Carbofuran.
# Found 1 groups of files with prefix Ferbam.
# Found 1 groups of files with prefix Dicofol.
# Found 1 groups of files with prefix Dimethylarsinic Acid.
# Found 1 groups of files with prefix Copper Sulfate.
# Found 1 groups of files with prefix Spiromesifen.
# Found 1 groups of files with prefix Prometon.
# Found 1 groups of files with prefix Methyl Parathion.
# Found 1 groups of files with prefix Propiconazole.
# Found 1 groups of files with prefix Chlorpyrifos.
# Found 1 groups of files with prefix Pendimethalin.
# Found 1 groups of files with prefix Msma.
# Found 1 groups of files with prefix Tri-Allate.
# Found 1 groups of files with prefix Boscalid.
# Found 1 groups of files with prefix Mancozeb.
# Found 1 groups of files with prefix Phosphoric Acid.
# Found 1 groups of files with prefix Propamocarb Hcl.
# Found 1 groups of files with prefix Clothianidin.
# Found 1 groups of files with prefix Iprodione.
# Found 1 groups of files with prefix Hydrated Lime.
# Found 1 groups of files with prefix 6-Benzyladenine.
# Found 1 groups of files with prefix Deltamethrin.
# Found 1 groups of files with prefix Etoxazole.
# Found 1 groups of files with prefix Bacillus Thuringiensis.
# Found 1 groups of files with prefix Clopyralid.
# Found 1 groups of files with prefix Acephate.
# Found 1 groups of files with prefix 2,4-Db.
# Found 1 groups of files with prefix Carboxin.
# Found 1 groups of files with prefix Diuron.
# Found 1 groups of files with prefix Cloransulam-Methyl.
# Found 1 groups of files with prefix Fluroxypyr.
# Found 1 groups of files with prefix Formetanate.
# Found 1 groups of files with prefix Nicosulfuron.
# Found 1 groups of files with prefix Isoxaflutole.
# Found 1 groups of files with prefix Fenbuconazole.
# Found 1 groups of files with prefix Glufosinate.
# Found 1 groups of files with prefix Permethrin.
# Found 1 groups of files with prefix Tralkoxydim.
# Found 1 groups of files with prefix Diazinon.
# Found 1 groups of files with prefix Mesotrione.
# Found 1 groups of files with prefix Tebupirimphos.
# Found 1 groups of files with prefix Pinolene.
# Found 1 groups of files with prefix Mecoprop.
# Found 1 groups of files with prefix Ziram.
# Found 1 groups of files with prefix Malathion.
# Found 1 groups of files with prefix Copper.
# Found 1 groups of files with prefix Sulfur.
# Found 1 groups of files with prefix Imazethapyr.
# Found 1 groups of files with prefix Cyazofamid.
# Found 1 groups of files with prefix Mcpa.
# Found 1 groups of files with prefix Endothal.
# Found 1 groups of files with prefix Maleic Hydrazide.
# Found 1 groups of files with prefix Cymoxanil.
# Found 1 groups of files with prefix Flumiclorac.
# Found 1 groups of files with prefix Coniothyrium Minitans.
# Found 1 groups of files with prefix Benomyl.
# Found 1 groups of files with prefix Mepiquat.
# Found 1 groups of files with prefix Chlorethoxyfos.
# Found 1 groups of files with prefix Pseudomonas Fluorescens.
# Found 1 groups of files with prefix Calcium Polysulfide.
# Found 1 groups of files with prefix Aviglycine.
# Found 1 groups of files with prefix Myrothecium Verrucaria.
# Found 1 groups of files with prefix Topramezone.
# Found 1 groups of files with prefix Linuron.
# Found 1 groups of files with prefix Eptc.
# Found 1 groups of files with prefix Triflusulfuron.
# Found 1 groups of files with prefix Fenoxaprop.
# Found 1 groups of files with prefix Sulfentrazone.
# Found 1 groups of files with prefix Tefluthrin.
# Found 1 groups of files with prefix Pyrimethanil.
# Found 1 groups of files with prefix Streptomycin.
# Found 1 groups of files with prefix Indolyl-Butyric Acid.
# Found 1 groups of files with prefix Dimethomorph.
# Found 1 groups of files with prefix Quizalofop.
# Found 1 groups of files with prefix Thifensulfuron.
# Found 1 groups of files with prefix Fluazinam.
# Found 1 groups of files with prefix Zinc.
# Found 1 groups of files with prefix Diflubenzuron.
# Found 1 groups of files with prefix Dicamba.
# Found 1 groups of files with prefix Fentin.
# Found 1 groups of files with prefix Novaluron.
# Found 1 groups of files with prefix Famoxadone.
# Found 1 groups of files with prefix Pyrithiobac-Sodium.
# Found 1 groups of files with prefix Norflurazon.
# Found 1 groups of files with prefix Prohexadione.
# Found 1 groups of files with prefix Fludioxonil.
# Found 1 groups of files with prefix Metiram.
# Found 1 groups of files with prefix Cyfluthrin.
# Found 1 groups of files with prefix Bensulfuron.
# Found 1 groups of files with prefix Metolachlor.
# Found 1 groups of files with prefix Cyclanilide.
# Found 1 groups of files with prefix Tebuconazole.
# Found 1 groups of files with prefix Fomesafen.
# Found 1 groups of files with prefix Triflumizole.
# Found 1 groups of files with prefix Aldicarb.
# Found 1 groups of files with prefix Oxyfluorfen.
# Found 1 groups of files with prefix Oxamyl.
# Found 1 groups of files with prefix Desmedipham.
# Found 1 groups of files with prefix Propanil.
# Found 1 groups of files with prefix Butylate.
# Found 1 groups of files with prefix Prometryn.
# Found 1 groups of files with prefix Copper Hydroxide.
# Found 1 groups of files with prefix Isoxaben.
# Found 1 groups of files with prefix Mesosulfuron.
# Found 1 groups of files with prefix Phenmedipham.
# Found 1 groups of files with prefix Diclosulam.
# Found 1 groups of files with prefix Cycloate.
# Found 1 groups of files with prefix Acibenzolar.
# Found 1 groups of files with prefix Chloridazon.
# Found 1 groups of files with prefix Imazamethabenz.
# Found 1 groups of files with prefix Molinate.
# Found 1 groups of files with prefix Azoxystrobin.
# Found 1 groups of files with prefix Dichloropropene.
# Found 1 groups of files with prefix Methomyl.
# Found 1 groups of files with prefix Copper Oxychloride.
# Found 1 groups of files with prefix Bensulide.
# Found 1 groups of files with prefix Naptalam.
# Found 1 groups of files with prefix Flonicamid.
# Found 1 groups of files with prefix Esfenvalerate.
# Found 1 groups of files with prefix Bifenthrin.
# Found 1 groups of files with prefix Dimethenamid.
# Found 1 groups of files with prefix Cyhalofop.
# Found 1 groups of files with prefix Bromacil.
# Found 1 groups of files with prefix Fenpyroximate.
# Found 1 groups of files with prefix Tebuthiuron.
# Found 1 groups of files with prefix Neem Oil.
# Found 1 groups of files with prefix Simazine.
# Found 1 groups of files with prefix Petroleum Oil.
# Found 1 groups of files with prefix Indoxacarb.
# Found 1 groups of files with prefix Dcpa.
# Found 1 groups of files with prefix Methamidophos.
# Found 1 groups of files with prefix Ethoprophos.
# Found 1 groups of files with prefix Sulfcarbamide.
# Found 295 unique prefixes in results/results_ICPSR_1992_EPEST_1997/raw
# Saving to results/results_ICPSR_1992_EPEST_1997
# Merging files:   0%|          | 0/295 [00:00<?, ?it/s]
# Found 1 groups of files with prefix Cyhalothrin-Lambda.
# Found 1 groups of files with prefix Copper.
# Found 1 groups of files with prefix Sulfur.
# Found 1 groups of files with prefix Imidacloprid.
# Found 1 groups of files with prefix Harpin Protein.
# Found 1 groups of files with prefix Imazethapyr.
# Found 1 groups of files with prefix Oxydemeton-Methyl.
# Found 1 groups of files with prefix Pymetrozine.
# Found 1 groups of files with prefix Tribufos.
# Found 1 groups of files with prefix Chloropicrin.
# Found 1 groups of files with prefix Lactofen.
# Found 1 groups of files with prefix Etridiazole.
# Found 1 groups of files with prefix Thiobencarb.
# Found 1 groups of files with prefix Zeta-Cypermethrin.
# Found 1 groups of files with prefix Metam Potassium.
# Found 1 groups of files with prefix Clodinafop.
# Found 1 groups of files with prefix Imazapic.
# Found 1 groups of files with prefix Mcpa.
# Found 1 groups of files with prefix Cuprous Oxide.
# Found 1 groups of files with prefix Benfluralin.
# Found 1 groups of files with prefix Endothal.
# Found 1 groups of files with prefix Butralin.
# Found 1 groups of files with prefix Azadirachtin.
# Found 1 groups of files with prefix Maleic Hydrazide.
# Found 1 groups of files with prefix Propachlor.
# Found 1 groups of files with prefix Pelargonic Acid.
# Found 1 groups of files with prefix Zoxamide.
# Found 1 groups of files with prefix Tetraconazole.
# Found 1 groups of files with prefix Lindane.
# Found 1 groups of files with prefix Maneb.
# Found 1 groups of files with prefix Pyridaben.
# Found 1 groups of files with prefix Diquat.
# Found 1 groups of files with prefix Thiazopyr.
# Found 1 groups of files with prefix Tribenuron Methyl.
# Found 1 groups of files with prefix Cymoxanil.
# Found 1 groups of files with prefix Flumiclorac.
# Found 1 groups of files with prefix Clomazone.
# Found 1 groups of files with prefix Bacillus Cereus.
# Found 1 groups of files with prefix Carbaryl.
# Found 1 groups of files with prefix Chlorothalonil.
# Found 1 groups of files with prefix Triasulfuron.
# Found 1 groups of files with prefix Methyl Bromide.
# Found 1 groups of files with prefix Mepiquat.
# Found 1 groups of files with prefix Benomyl.
# Found 1 groups of files with prefix Chlorethoxyfos.
# Found 1 groups of files with prefix Quintozene.
# Found 1 groups of files with prefix Metam.
# Found 1 groups of files with prefix Pseudomonas Fluorescens.
# Found 1 groups of files with prefix Calcium Polysulfide.
# Found 1 groups of files with prefix Fenbutatin Oxide.
# Found 1 groups of files with prefix Malathion.
# Found 1 groups of files with prefix Oxytetracycline.
# Found 1 groups of files with prefix Atrazine.
# Found 1 groups of files with prefix Aviglycine.
# Found 1 groups of files with prefix Myrothecium Verrucaria.
# Found 1 groups of files with prefix Rotenone.
# Found 1 groups of files with prefix Hexazinone.
# Found 1 groups of files with prefix Dichlobenil.
# Found 1 groups of files with prefix Dimethomorph.
# Found 1 groups of files with prefix Linuron.
# Found 1 groups of files with prefix Eptc.
# Found 1 groups of files with prefix Gibberellic Acid.
# Found 1 groups of files with prefix Metribuzin.
# Found 1 groups of files with prefix Triflusulfuron.
# Found 1 groups of files with prefix Dimethoate.
# Found 1 groups of files with prefix Flumetralin.
# Found 1 groups of files with prefix Bromoxynil.
# Found 1 groups of files with prefix Thiodicarb.
# Found 1 groups of files with prefix Hexythiazox.
# Found 1 groups of files with prefix Prosulfuron.
# Found 1 groups of files with prefix Fenoxaprop.
# Found 1 groups of files with prefix Copper Oxychloride S.
# Found 1 groups of files with prefix Sulfentrazone.
# Found 1 groups of files with prefix Fluazifop.
# Found 1 groups of files with prefix Cytokinin.
# Found 1 groups of files with prefix Bacillus Subtilis.
# Found 1 groups of files with prefix Thiram.
# Found 1 groups of files with prefix Bentazone.
# Found 1 groups of files with prefix Methidathion.
# Found 1 groups of files with prefix Tefluthrin.
# Found 1 groups of files with prefix Metolachlor-S.
# Found 1 groups of files with prefix Streptomycin.
# Found 1 groups of files with prefix Paraquat.
# Found 1 groups of files with prefix Ethion.
# Found 1 groups of files with prefix Emamectin.
# Found 1 groups of files with prefix Propyzamide.
# Found 1 groups of files with prefix Indolyl-Butyric Acid.
# Found 1 groups of files with prefix Quizalofop.
# Found 1 groups of files with prefix Naphthylacetic Acid.
# Found 1 groups of files with prefix Terbacil.
# Found 1 groups of files with prefix Flutolanil.
# Found 1 groups of files with prefix Zinc.
# Found 1 groups of files with prefix Diflubenzuron.
# Found 1 groups of files with prefix Thifensulfuron.
# Found 1 groups of files with prefix Myclobutanil.
# Found 1 groups of files with prefix Fluazinam.
# Found 1 groups of files with prefix Trifloxystrobin.
# Found 1 groups of files with prefix Dicamba.
# Found 1 groups of files with prefix Propargite.
# Found 1 groups of files with prefix Mefenoxam.
# Found 1 groups of files with prefix Amitraz.
# Found 1 groups of files with prefix Fentin.
# Found 1 groups of files with prefix Disulfoton.
# Found 1 groups of files with prefix Fenhexamid.
# Found 1 groups of files with prefix Captan.
# Found 1 groups of files with prefix Pyridate.
# Found 1 groups of files with prefix Petroleum Distillate.
# Found 1 groups of files with prefix Tralomethrin.
# Found 1 groups of files with prefix Mcpb.
# Found 1 groups of files with prefix Ethephon.
# Found 1 groups of files with prefix Carbofuran.
# Found 1 groups of files with prefix Ferbam.
# Found 1 groups of files with prefix Dichlorprop.
# Found 1 groups of files with prefix Pyrithiobac-Sodium.
# Found 1 groups of files with prefix Imazaquin.
# Found 1 groups of files with prefix Sodium Chlorate.
# Found 1 groups of files with prefix Dicofol.
# Found 1 groups of files with prefix Diclofop.
# Found 1 groups of files with prefix Kaolin Clay.
# Found 1 groups of files with prefix Fipronil.
# Found 1 groups of files with prefix Imazapyr.
# Found 1 groups of files with prefix Dimethylarsinic Acid.
# Found 1 groups of files with prefix Copper Sulfate.
# Found 1 groups of files with prefix Phorate.
# Found 1 groups of files with prefix Ethalfluralin.
# Found 1 groups of files with prefix Norflurazon.
# Found 1 groups of files with prefix Terbufos.
# Found 1 groups of files with prefix Prometon.
# Found 1 groups of files with prefix Trifluralin.
# Found 1 groups of files with prefix Prohexadione.
# Found 1 groups of files with prefix Fludioxonil.
# Found 1 groups of files with prefix Methyl Parathion.
# Found 1 groups of files with prefix Aluminum Phosphide.
# Found 1 groups of files with prefix Fatty Alcohols.
# Found 1 groups of files with prefix Metiram.
# Found 1 groups of files with prefix Propiconazole.
# Found 1 groups of files with prefix Acifluorfen.
# Found 1 groups of files with prefix Dicloran.
# Found 1 groups of files with prefix Cyfluthrin.
# Found 1 groups of files with prefix Chlorpyrifos.
# Found 1 groups of files with prefix Decan-1-Ol.
# Found 1 groups of files with prefix Bensulfuron.
# Found 1 groups of files with prefix Flufenacet.
# Found 1 groups of files with prefix Metalaxyl.
# Found 1 groups of files with prefix 2,4-D.
# Found 1 groups of files with prefix Pendimethalin.
# Found 1 groups of files with prefix Flucarbazone.
# Found 1 groups of files with prefix Fluometuron.
# Found 1 groups of files with prefix Msma.
# Found 1 groups of files with prefix Napropamide.
# Found 1 groups of files with prefix Metolachlor.
# Found 1 groups of files with prefix Cyclanilide.
# Found 1 groups of files with prefix Quinclorac.
# Found 1 groups of files with prefix Oryzalin.
# Found 1 groups of files with prefix Sulfometuron.
# Found 1 groups of files with prefix Cryolite.
# Found 1 groups of files with prefix Tri-Allate.
# Found 1 groups of files with prefix Tebuconazole.
# Found 1 groups of files with prefix Mancozeb.
# Found 1 groups of files with prefix Buprofezin.
# Found 1 groups of files with prefix Dimethipin.
# Found 1 groups of files with prefix Fomesafen.
# Found 1 groups of files with prefix Pyriproxyfen.
# Found 1 groups of files with prefix Cyromazine.
# Found 1 groups of files with prefix Triflumizole.
# Found 1 groups of files with prefix Abamectin.
# Found 1 groups of files with prefix Phosphoric Acid.
# Found 1 groups of files with prefix Aldicarb.
# Found 1 groups of files with prefix Metaldehyde.
# Found 1 groups of files with prefix Oxyfluorfen.
# Found 1 groups of files with prefix Methoxyfenozide.
# Found 1 groups of files with prefix Desmedipham.
# Found 1 groups of files with prefix Oxamyl.
# Found 1 groups of files with prefix Fenamiphos.
# Found 1 groups of files with prefix Propanil.
# Found 1 groups of files with prefix Flumetsulam.
# Found 1 groups of files with prefix Butylate.
# Found 1 groups of files with prefix Prometryn.
# Found 1 groups of files with prefix Copper Hydroxide.
# Found 1 groups of files with prefix Potassium Bicarbonate.
# Found 1 groups of files with prefix Isoxaben.
# Found 1 groups of files with prefix Propamocarb Hcl.
# Found 1 groups of files with prefix Cyprodinil.
# Found 1 groups of files with prefix Azinphos-Methyl.
# Found 1 groups of files with prefix Iprodione.
# Found 1 groups of files with prefix Naphthylacetamide.
# Found 1 groups of files with prefix Thidiazuron.
# Found 1 groups of files with prefix Triadimefon.
# Found 1 groups of files with prefix Phenmedipham.
# Found 1 groups of files with prefix Fenpropathrin.
# Found 1 groups of files with prefix Cycloate.
# Found 1 groups of files with prefix Diclosulam.
# Found 1 groups of files with prefix Dimethenamid-P.
# Found 1 groups of files with prefix Methoxychlor.
# Found 1 groups of files with prefix Hydrated Lime.
# Found 1 groups of files with prefix Glyphosate.
# Found 1 groups of files with prefix 6-Benzyladenine.
# Found 1 groups of files with prefix Acibenzolar.
# Found 1 groups of files with prefix Deltamethrin.
# Found 1 groups of files with prefix Naled.
# Found 1 groups of files with prefix Kresoxim-Methyl.
# Found 1 groups of files with prefix Chloridazon.
# Found 1 groups of files with prefix Bacillus Thuringiensis.
# Found 1 groups of files with prefix Chlorsulfuron.
# Found 1 groups of files with prefix Dodine.
# Found 1 groups of files with prefix Clopyralid.
# Found 1 groups of files with prefix Fosetyl.
# Found 1 groups of files with prefix Potassium Oleate.
# Found 1 groups of files with prefix Sulfosate.
# Found 1 groups of files with prefix Imazamethabenz.
# Found 1 groups of files with prefix Molinate.
# Found 1 groups of files with prefix Cyanazine.
# Found 1 groups of files with prefix Diflufenzopyr.
# Found 1 groups of files with prefix Acephate.
# Found 1 groups of files with prefix Azoxystrobin.
# Found 1 groups of files with prefix Vinclozolin.
# Found 1 groups of files with prefix Sulfosulfuron.
# Found 1 groups of files with prefix Dichloropropene.
# Found 1 groups of files with prefix 2,4-Db.
# Found 1 groups of files with prefix Alachlor.
# Found 1 groups of files with prefix Pebulate.
# Found 1 groups of files with prefix Difenzoquat.
# Found 1 groups of files with prefix Garlic Juice.
# Found 1 groups of files with prefix Cypermethrin.
# Found 1 groups of files with prefix Diuron.
# Found 1 groups of files with prefix Methomyl.
# Found 1 groups of files with prefix L-Glutamic Acid.
# Found 1 groups of files with prefix Tetraoxosulfate.
# Found 1 groups of files with prefix Tebufenozide.
# Found 1 groups of files with prefix Cloransulam-Methyl.
# Found 1 groups of files with prefix Copper Oxychloride.
# Found 1 groups of files with prefix Rimsulfuron.
# Found 1 groups of files with prefix Metsulfuron.
# Found 1 groups of files with prefix Bensulide.
# Found 1 groups of files with prefix Naptalam.
# Found 1 groups of files with prefix Thiamethoxam.
# Found 1 groups of files with prefix Esfenvalerate.
# Found 1 groups of files with prefix Cinnamaldehyde.
# Found 1 groups of files with prefix Fluroxypyr.
# Found 1 groups of files with prefix Formetanate.
# Found 1 groups of files with prefix Acetochlor.
# Found 1 groups of files with prefix Bifenthrin.
# Found 1 groups of files with prefix Sethoxydim.
# Found 1 groups of files with prefix Dimethenamid.
# Found 1 groups of files with prefix Triforine.
# Found 1 groups of files with prefix Flumioxazin.
# Found 1 groups of files with prefix Picloram.
# Found 1 groups of files with prefix Triclopyr.
# Found 1 groups of files with prefix Bromacil.
# Found 1 groups of files with prefix Sulfuric Acid.
# Found 1 groups of files with prefix Hydroxypropanoic Acid.
# Found 1 groups of files with prefix Hydrogen Peroxide.
# Found 1 groups of files with prefix Bordeaux Mixture.
# Found 1 groups of files with prefix Dicrotophos.
# Found 1 groups of files with prefix Ethofumesate.
# Found 1 groups of files with prefix Nicosulfuron.
# Found 1 groups of files with prefix Piperonyl Butoxide.
# Found 1 groups of files with prefix Endosulfan.
# Found 1 groups of files with prefix Isoxaflutole.
# Found 1 groups of files with prefix Tebuthiuron.
# Found 1 groups of files with prefix Halosulfuron.
# Found 1 groups of files with prefix Clethodim.
# Found 1 groups of files with prefix Profenofos.
# Found 1 groups of files with prefix Neem Oil.
# Found 1 groups of files with prefix Gamma Aminobutyric Acid.
# Found 1 groups of files with prefix Fenbuconazole.
# Found 1 groups of files with prefix Glufosinate.
# Found 1 groups of files with prefix Permethrin.
# Found 1 groups of files with prefix Pyrethrins.
# Found 1 groups of files with prefix Phosmet.
# Found 1 groups of files with prefix Copper Sulf Tribasic.
# Found 1 groups of files with prefix Tralkoxydim.
# Found 1 groups of files with prefix Simazine.
# Found 1 groups of files with prefix Diazinon.
# Found 1 groups of files with prefix Dsma.
# Found 1 groups of files with prefix Mesotrione.
# Found 1 groups of files with prefix Tebupirimphos.
# Found 1 groups of files with prefix Petroleum Oil.
# Found 1 groups of files with prefix Indoxacarb.
# Found 1 groups of files with prefix Imazamox.
# Found 1 groups of files with prefix Thiophanate-Methyl.
# Found 1 groups of files with prefix Clofentezine.
# Found 1 groups of files with prefix Primisulfuron.
# Found 1 groups of files with prefix Pinolene.
# Found 1 groups of files with prefix Spinosyn.
# Found 1 groups of files with prefix Dcpa.
# Found 1 groups of files with prefix Methamidophos.
# Found 1 groups of files with prefix Ametryn.
# Found 1 groups of files with prefix Ziram.
# Found 1 groups of files with prefix Ethoprophos.
# Found 1 groups of files with prefix Mecoprop.
# Found 1 groups of files with prefix Carfentrazone-Ethyl.
# Found 1 groups of files with prefix Fenarimol.
# Found 1 groups of files with prefix Chlorimuron.
# Found 1 groups of files with prefix Sulfcarbamide.
# Found 314 unique prefixes in results/results_ICPSR_1992_EPEST_2001/raw
# Saving to results/results_ICPSR_1992_EPEST_2001
# Merging files:   0%|          | 0/314 [00:00<?, ?it/s]
# Found 1 groups of files with prefix Chloropicrin.
# Found 1 groups of files with prefix Zeta-Cypermethrin.
# Found 1 groups of files with prefix Clodinafop.
# Found 1 groups of files with prefix Butralin.
# Found 1 groups of files with prefix Pelargonic Acid.
# Found 1 groups of files with prefix Maneb.
# Found 1 groups of files with prefix Pyridaben.
# Found 1 groups of files with prefix Diquat.
# Found 1 groups of files with prefix Pyraflufen Ethyl.
# Found 1 groups of files with prefix Iodosulfuron.
# Found 1 groups of files with prefix Metam.
# Found 1 groups of files with prefix Atrazine.
# Found 1 groups of files with prefix Thiodicarb.
# Found 1 groups of files with prefix Hexythiazox.
# Found 1 groups of files with prefix Bacillus Subtilis.
# Found 1 groups of files with prefix Thiram.
# Found 1 groups of files with prefix Etridiazole.
# Found 1 groups of files with prefix Imazapic.
# Found 1 groups of files with prefix Potassium Oleate.
# Found 1 groups of files with prefix Myclobutanil.
# Found 1 groups of files with prefix Mefenoxam.
# Found 1 groups of files with prefix Acequinocyl.
# Found 1 groups of files with prefix Tralomethrin.
# Found 1 groups of files with prefix Mcpb.
# Found 1 groups of files with prefix Sodium Chlorate.
# Found 1 groups of files with prefix Diclofop.
# Found 1 groups of files with prefix Fenamidone.
# Found 1 groups of files with prefix Phorate.
# Found 1 groups of files with prefix Terbufos.
# Found 1 groups of files with prefix Fatty Alcohols.
# Found 1 groups of files with prefix Acifluorfen.
# Found 1 groups of files with prefix Dicloran.
# Found 1 groups of files with prefix Flufenacet.
# Found 1 groups of files with prefix Metalaxyl.
# Found 1 groups of files with prefix 2,4-D.
# Found 1 groups of files with prefix Quinclorac.
# Found 1 groups of files with prefix Cryolite.
# Found 1 groups of files with prefix Buprofezin.
# Found 1 groups of files with prefix Dimethipin.
# Found 1 groups of files with prefix Bispyribac.
# Found 1 groups of files with prefix Cyromazine.
# Found 1 groups of files with prefix Metaldehyde.
# Found 1 groups of files with prefix Methoxyfenozide.
# Found 1 groups of files with prefix Fenamiphos.
# Found 1 groups of files with prefix Flumetsulam.
# Found 1 groups of files with prefix Potassium Bicarbonate.
# Found 1 groups of files with prefix Triadimefon.
# Found 1 groups of files with prefix Fenpropathrin.
# Found 1 groups of files with prefix Dimethenamid-P.
# Found 1 groups of files with prefix Methoxychlor.
# Found 1 groups of files with prefix Naled.
# Found 1 groups of files with prefix Fosetyl.
# Found 1 groups of files with prefix Chlorsulfuron.
# Found 1 groups of files with prefix Dodine.
# Found 1 groups of files with prefix Cyanazine.
# Found 1 groups of files with prefix Sulfosulfuron.
# Found 1 groups of files with prefix Difenzoquat.
# Found 1 groups of files with prefix Cypermethrin.
# Found 1 groups of files with prefix L-Glutamic Acid.
# Found 1 groups of files with prefix Tebufenozide.
# Found 1 groups of files with prefix Rimsulfuron.
# Found 1 groups of files with prefix Propoxycarbazone.
# Found 1 groups of files with prefix Thiamethoxam.
# Found 1 groups of files with prefix Acetochlor.
# Found 1 groups of files with prefix Flumioxazin.
# Found 1 groups of files with prefix Pyraclostrobin.
# Found 1 groups of files with prefix Sulfuric Acid.
# Found 1 groups of files with prefix Dicrotophos.
# Found 1 groups of files with prefix Piperonyl Butoxide.
# Found 1 groups of files with prefix Halosulfuron.
# Found 1 groups of files with prefix Phosmet.
# Found 1 groups of files with prefix Carfentrazone-Ethyl.
# Found 1 groups of files with prefix Fenarimol.
# Found 1 groups of files with prefix Cyhalothrin-Lambda.
# Found 1 groups of files with prefix Pymetrozine.
# Found 1 groups of files with prefix Oxydemeton-Methyl.
# Found 1 groups of files with prefix Tribufos.
# Found 1 groups of files with prefix Cuprous Oxide.
# Found 1 groups of files with prefix Benfluralin.
# Found 1 groups of files with prefix Tetraconazole.
# Found 1 groups of files with prefix Thiazopyr.
# Found 1 groups of files with prefix Clomazone.
# Found 1 groups of files with prefix Chlorothalonil.
# Found 1 groups of files with prefix Bifenazate.
# Found 1 groups of files with prefix Rotenone.
# Found 1 groups of files with prefix Hexazinone.
# Found 1 groups of files with prefix Metribuzin.
# Found 1 groups of files with prefix Gibberellic Acid.
# Found 1 groups of files with prefix Trifloxysulfuron.
# Found 1 groups of files with prefix Flumetralin.
# Found 1 groups of files with prefix Bromoxynil.
# Found 1 groups of files with prefix Prosulfuron.
# Found 1 groups of files with prefix Copper Oxychloride S.
# Found 1 groups of files with prefix Fluazifop.
# Found 1 groups of files with prefix Bentazone.
# Found 1 groups of files with prefix Bordeaux Mixture.
# Found 1 groups of files with prefix Emamectin.
# Found 1 groups of files with prefix Propyzamide.
# Found 1 groups of files with prefix Flutolanil.
# Found 1 groups of files with prefix Terbacil.
# Found 1 groups of files with prefix Propargite.
# Found 1 groups of files with prefix Fenhexamid.
# Found 1 groups of files with prefix Captan.
# Found 1 groups of files with prefix Ethephon.
# Found 1 groups of files with prefix Bacillus Pumilis.
# Found 1 groups of files with prefix Spirodiclofen.
# Found 1 groups of files with prefix Imazaquin.
# Found 1 groups of files with prefix Kaolin Clay.
# Found 1 groups of files with prefix Fipronil.
# Found 1 groups of files with prefix Imazapyr.
# Found 1 groups of files with prefix Ethalfluralin.
# Found 1 groups of files with prefix Trifluralin.
# Found 1 groups of files with prefix Aluminum Phosphide.
# Found 1 groups of files with prefix Decan-1-Ol.
# Found 1 groups of files with prefix Flucarbazone.
# Found 1 groups of files with prefix Fluometuron.
# Found 1 groups of files with prefix Foramsulfuron.
# Found 1 groups of files with prefix Napropamide.
# Found 1 groups of files with prefix Oryzalin.
# Found 1 groups of files with prefix Thiacloprid.
# Found 1 groups of files with prefix Acetamiprid.
# Found 1 groups of files with prefix Pyriproxyfen.
# Found 1 groups of files with prefix Abamectin.
# Found 1 groups of files with prefix Cydia Pomonella.
# Found 1 groups of files with prefix Quinoxyfen.
# Found 1 groups of files with prefix Azinphos-Methyl.
# Found 1 groups of files with prefix Naphthylacetamide.
# Found 1 groups of files with prefix Thidiazuron.
# Found 1 groups of files with prefix Glyphosate.
# Found 1 groups of files with prefix Kresoxim-Methyl.
# Found 1 groups of files with prefix Sulfosate.
# Found 1 groups of files with prefix Vinclozolin.
# Found 1 groups of files with prefix Diflufenzopyr.
# Found 1 groups of files with prefix Alachlor.
# Found 1 groups of files with prefix Pebulate.
# Found 1 groups of files with prefix Tetraborohydrate.
# Found 1 groups of files with prefix Metsulfuron.
# Found 1 groups of files with prefix Sethoxydim.
# Found 1 groups of files with prefix Picloram.
# Found 1 groups of files with prefix Triclopyr.
# Found 1 groups of files with prefix Hydrogen Peroxide.
# Found 1 groups of files with prefix Ethofumesate.
# Found 1 groups of files with prefix Cyhalothrin-Gamma.
# Found 1 groups of files with prefix Endosulfan.
# Found 1 groups of files with prefix Clethodim.
# Found 1 groups of files with prefix Profenofos.
# Found 1 groups of files with prefix Gamma Aminobutyric Acid.
# Found 1 groups of files with prefix Pyrethrins.
# Found 1 groups of files with prefix Copper Sulf Tribasic.
# Found 1 groups of files with prefix Imazamox.
# Found 1 groups of files with prefix Thiophanate-Methyl.
# Found 1 groups of files with prefix Clofentezine.
# Found 1 groups of files with prefix Primisulfuron.
# Found 1 groups of files with prefix Ametryn.
# Found 1 groups of files with prefix Chlorimuron.
# Found 1 groups of files with prefix Imidacloprid.
# Found 1 groups of files with prefix Harpin Protein.
# Found 1 groups of files with prefix Lactofen.
# Found 1 groups of files with prefix Thiobencarb.
# Found 1 groups of files with prefix Metam Potassium.
# Found 1 groups of files with prefix Azadirachtin.
# Found 1 groups of files with prefix Zoxamide.
# Found 1 groups of files with prefix Lindane.
# Found 1 groups of files with prefix Tribenuron Methyl.
# Found 1 groups of files with prefix Bacillus Cereus.
# Found 1 groups of files with prefix Carbaryl.
# Found 1 groups of files with prefix Triasulfuron.
# Found 1 groups of files with prefix Methyl Bromide.
# Found 1 groups of files with prefix Quintozene.
# Found 1 groups of files with prefix Oxytetracycline.
# Found 1 groups of files with prefix Fenbutatin Oxide.
# Found 1 groups of files with prefix Dichlobenil.
# Found 1 groups of files with prefix Penoxsulam.
# Found 1 groups of files with prefix Dimethoate.
# Found 1 groups of files with prefix Cytokinin.
# Found 1 groups of files with prefix Methidathion.
# Found 1 groups of files with prefix Metolachlor-S.
# Found 1 groups of files with prefix Cyprodinil.
# Found 1 groups of files with prefix Paraquat.
# Found 1 groups of files with prefix Dichlorprop.
# Found 1 groups of files with prefix Spinosyn.
# Found 1 groups of files with prefix Naphthylacetic Acid.
# Found 1 groups of files with prefix Trifloxystrobin.
# Found 1 groups of files with prefix Disulfoton.
# Found 1 groups of files with prefix Petroleum Distillate.
# Found 1 groups of files with prefix Carbofuran.
# Found 1 groups of files with prefix Ferbam.
# Found 1 groups of files with prefix Dicofol.
# Found 1 groups of files with prefix Dimethylarsinic Acid.
# Found 1 groups of files with prefix Copper Sulfate.
# Found 1 groups of files with prefix Spiromesifen.
# Found 1 groups of files with prefix Prometon.
# Found 1 groups of files with prefix Methyl Parathion.
# Found 1 groups of files with prefix Propiconazole.
# Found 1 groups of files with prefix Chlorpyrifos.
# Found 1 groups of files with prefix Pendimethalin.
# Found 1 groups of files with prefix Msma.
# Found 1 groups of files with prefix Tri-Allate.
# Found 1 groups of files with prefix Boscalid.
# Found 1 groups of files with prefix Mancozeb.
# Found 1 groups of files with prefix Phosphoric Acid.
# Found 1 groups of files with prefix Propamocarb Hcl.
# Found 1 groups of files with prefix Clothianidin.
# Found 1 groups of files with prefix Iprodione.
# Found 1 groups of files with prefix Hydrated Lime.
# Found 1 groups of files with prefix 6-Benzyladenine.
# Found 1 groups of files with prefix Deltamethrin.
# Found 1 groups of files with prefix Etoxazole.
# Found 1 groups of files with prefix Bacillus Thuringiensis.
# Found 1 groups of files with prefix Clopyralid.
# Found 1 groups of files with prefix Acephate.
# Found 1 groups of files with prefix 2,4-Db.
# Found 1 groups of files with prefix Diuron.
# Found 1 groups of files with prefix Cloransulam-Methyl.
# Found 1 groups of files with prefix Fluroxypyr.
# Found 1 groups of files with prefix Formetanate.
# Found 1 groups of files with prefix Nicosulfuron.
# Found 1 groups of files with prefix Isoxaflutole.
# Found 1 groups of files with prefix Fenbuconazole.
# Found 1 groups of files with prefix Glufosinate.
# Found 1 groups of files with prefix Permethrin.
# Found 1 groups of files with prefix Tralkoxydim.
# Found 1 groups of files with prefix Diazinon.
# Found 1 groups of files with prefix Mesotrione.
# Found 1 groups of files with prefix Tebupirimphos.
# Found 1 groups of files with prefix Pinolene.
# Found 1 groups of files with prefix Mecoprop.
# Found 1 groups of files with prefix Ziram.
# Found 1 groups of files with prefix Malathion.
# Found 1 groups of files with prefix Copper.
# Found 1 groups of files with prefix Sulfur.
# Found 1 groups of files with prefix Imazethapyr.
# Found 1 groups of files with prefix Mcpa.
# Found 1 groups of files with prefix Endothal.
# Found 1 groups of files with prefix Maleic Hydrazide.
# Found 1 groups of files with prefix Cymoxanil.
# Found 1 groups of files with prefix Flumiclorac.
# Found 1 groups of files with prefix Coniothyrium Minitans.
# Found 1 groups of files with prefix Benomyl.
# Found 1 groups of files with prefix Mepiquat.
# Found 1 groups of files with prefix Chlorethoxyfos.
# Found 1 groups of files with prefix Pseudomonas Fluorescens.
# Found 1 groups of files with prefix Calcium Polysulfide.
# Found 1 groups of files with prefix Aviglycine.
# Found 1 groups of files with prefix Myrothecium Verrucaria.
# Found 1 groups of files with prefix Linuron.
# Found 1 groups of files with prefix Eptc.
# Found 1 groups of files with prefix Triflusulfuron.
# Found 1 groups of files with prefix Fenoxaprop.
# Found 1 groups of files with prefix Sulfentrazone.
# Found 1 groups of files with prefix Tefluthrin.
# Found 1 groups of files with prefix Pyrimethanil.
# Found 1 groups of files with prefix Streptomycin.
# Found 1 groups of files with prefix Indolyl-Butyric Acid.
# Found 1 groups of files with prefix Dimethomorph.
# Found 1 groups of files with prefix Quizalofop.
# Found 1 groups of files with prefix Thifensulfuron.
# Found 1 groups of files with prefix Fluazinam.
# Found 1 groups of files with prefix Zinc.
# Found 1 groups of files with prefix Diflubenzuron.
# Found 1 groups of files with prefix Dicamba.
# Found 1 groups of files with prefix Fentin.
# Found 1 groups of files with prefix Novaluron.
# Found 1 groups of files with prefix Famoxadone.
# Found 1 groups of files with prefix Pyrithiobac-Sodium.
# Found 1 groups of files with prefix Norflurazon.
# Found 1 groups of files with prefix Prohexadione.
# Found 1 groups of files with prefix Fludioxonil.
# Found 1 groups of files with prefix Metiram.
# Found 1 groups of files with prefix Cyfluthrin.
# Found 1 groups of files with prefix Bensulfuron.
# Found 1 groups of files with prefix Metolachlor.
# Found 1 groups of files with prefix Cyclanilide.
# Found 1 groups of files with prefix Tebuconazole.
# Found 1 groups of files with prefix Fomesafen.
# Found 1 groups of files with prefix Triflumizole.
# Found 1 groups of files with prefix Aldicarb.
# Found 1 groups of files with prefix Oxyfluorfen.
# Found 1 groups of files with prefix Oxamyl.
# Found 1 groups of files with prefix Desmedipham.
# Found 1 groups of files with prefix Propanil.
# Found 1 groups of files with prefix Butylate.
# Found 1 groups of files with prefix Prometryn.
# Found 1 groups of files with prefix Copper Hydroxide.
# Found 1 groups of files with prefix Isoxaben.
# Found 1 groups of files with prefix Mesosulfuron.
# Found 1 groups of files with prefix Phenmedipham.
# Found 1 groups of files with prefix Diclosulam.
# Found 1 groups of files with prefix Cycloate.
# Found 1 groups of files with prefix Acibenzolar.
# Found 1 groups of files with prefix Chloridazon.
# Found 1 groups of files with prefix Imazamethabenz.
# Found 1 groups of files with prefix Molinate.
# Found 1 groups of files with prefix Azoxystrobin.
# Found 1 groups of files with prefix Dichloropropene.
# Found 1 groups of files with prefix Methomyl.
# Found 1 groups of files with prefix Copper Oxychloride.
# Found 1 groups of files with prefix Bensulide.
# Found 1 groups of files with prefix Naptalam.
# Found 1 groups of files with prefix Esfenvalerate.
# Found 1 groups of files with prefix Bifenthrin.
# Found 1 groups of files with prefix Dimethenamid.
# Found 1 groups of files with prefix Cyhalofop.
# Found 1 groups of files with prefix Bromacil.
# Found 1 groups of files with prefix Fenpyroximate.
# Found 1 groups of files with prefix Tebuthiuron.
# Found 1 groups of files with prefix Neem Oil.
# Found 1 groups of files with prefix Simazine.
# Found 1 groups of files with prefix Petroleum Oil.
# Found 1 groups of files with prefix Indoxacarb.
# Found 1 groups of files with prefix Dcpa.
# Found 1 groups of files with prefix Methamidophos.
# Found 1 groups of files with prefix Ethoprophos.
# Found 1 groups of files with prefix Sulfcarbamide.
