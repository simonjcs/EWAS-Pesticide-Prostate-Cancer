# %%
import pandas as pd
from glob import glob
import os
from tqdm.notebook import tqdm

# %%
importance_col = "RF importance (permute)"
top_n = 10

# %%
results_paths = glob("results/results_*")
results_paths
# Out:
# ['results/results_ICPSR_1992_EPEST_2003',
#  'results/results_ICPSR_1992_EPEST_2002',
#  'results/results_ICPSR_1992_EPEST_1997',
#  'results/results_ICPSR_1992_EPEST_2001']

# %%
data_folder = "/Users/dslim/pesticide_rf_xgboost/data"
data_path = os.path.join(data_folder, "1992_Tab_v2/DS0042/35206-0042-Data.tsv")

feature_df = pd.read_csv(data_path, sep="\t")
feature_df = feature_df.set_index("fips")
cols_to_drop = [col for col in feature_df.columns if "flag" in col.lower()]
feature_df = feature_df.drop(columns=cols_to_drop)
feature_df.head()
# Out:
# <ipython-input-4-ea461949017c>:4: DtypeWarning: Columns (71,73,507,509,1461,1463) have mixed types. Specify dtype option on import or set low_memory=False.
#   feature_df = pd.read_csv(data_path, sep="\t")
#       state  county           name  level  statefip  counfip  item010001  \
# fips
# 0       100       0  UNITED STATES      3         0        0     1925300
# 1000     41       0        ALABAMA      2         1        0       37905
# 1001     41      10        AUTAUGA      1         1        1         322
# 1003     41      30        BALDWIN      1         1        3         941
# 1005     41      50        BARBOUR      1         1        5         421
#
#       item010002  item010003  item010004  ...  item390003  item390004  \
# fips                                      ...
# 0      945531520         491      357056  ...        5133        4056
# 1000     8450823         223      220265  ...          56          16
# 1001      107259         333      226198  ...           0           0
# 1003      167832         178      240396  ...           0           0
# 1005      177189         421      327882  ...           0           0
#
#       item390005  item390006  item390007  item390008  item390009  item390010  \
# fips
# 0           3186        3670        3701       10498        9232       12927
# 1000           3           3           3           0          15          11
# 1001           0           0           0           0           0           0
# 1003           0           0           0           0           0           0
# 1005           0           0           0           0           0           0
#
#       item390011  item390012
# fips
# 0           2000       11831
# 1000          10          60
# 1001           0           0
# 1003           0           0
# 1005           0           0
#
# [5 rows x 2787 columns]

# %%
index_cols = feature_df.columns[:6].tolist()
index_cols
# Out:
# ['state', 'county', 'name', 'level', 'statefip', 'counfip']

# %%
def get_top_n_features(output_folder, pesticide_name, top_feat_codes):
    top_n_feature_df = feature_df[index_cols + top_feat_codes]

    csv_name = (
        os.path.join(output_folder, pesticide_name) +
        f"_top_{top_n}_features.csv"
    )
    top_n_feature_df = top_n_feature_df[~(top_n_feature_df.county == 0)]
    top_n_feature_df = top_n_feature_df.drop(
        ["state", "county", "level"], axis=1)
    top_n_feature_df.to_csv(csv_name)


def filter_df(feat_importance_df, corr_df, threshold=0.8, top_n=10):
    top_filtered_feature_n = 0
    total_feat_n = feat_importance_df.shape[0]

    feat_importance_df_filtered = feat_importance_df.copy()
    # display(feat_importance_df)
    # display(corr_df)
    while top_filtered_feature_n < top_n:
        feat_code = feat_importance_df_filtered.index[top_filtered_feature_n]
        print(
            f"Filtering {feat_code} ({feat_importance_df_filtered.loc[feat_code, 'feature_name']})"
        )
        # display(corr_df[feat_code])
        feat_to_keep = corr_df[feat_code].loc[
            feat_importance_df_filtered.index.tolist()
        ]

        feat_to_keep = feat_to_keep[feat_to_keep < threshold].index.tolist() + [
            feat_code
        ]
        feat_to_keep_n = len(feat_to_keep)
        print(
            f"Keeping {feat_to_keep_n}/{total_feat_n} ({feat_to_keep_n/total_feat_n*100:.1f}%) features"
        )

        feat_importance_df_filtered = feat_importance_df_filtered.loc[
            feat_to_keep
        ].sort_values(importance_col, ascending=False)
        print(feat_importance_df_filtered.shape)
        # display(feat_importance_df_filtered.head(10))
        top_filtered_feature_n += 1
    return feat_importance_df_filtered


def get_top_n_feature_info(
    output_folder,
    result_path,
    pesticide_name,
    top_n=10,
    corr_threshold=0.9,
    filter_by_corr=True,
    corr_df=None,
):
    feat_importance_df = pd.read_csv(result_path, index_col=0)
    feat_importance_df[importance_col] = pd.to_numeric(
        feat_importance_df[importance_col]
    )

    feat_importance_df.sort_values(
        importance_col, ascending=False, inplace=True)
    # display(feat_importance_df)
    if filter_by_corr:
        feat_importance_df["rank"] = range(1, feat_importance_df.shape[0] + 1)
        feat_importance_df = filter_df(
            feat_importance_df, corr_df, threshold=corr_threshold, top_n=top_n
        )
    feat_importance_df = feat_importance_df.iloc[:top_n]
    top_feats = feat_importance_df["feature_name"]

    top_feats_path = os.path.join(
        output_folder, f"{pesticide_name}_top_{top_n}_feature_info.csv"
    )
    feat_importance_df.to_csv(top_feats_path, index=False)
    top_feat_codes = top_feats.index.tolist()

    return top_feat_codes

# %%
corr_threshold = 0.9
filter_by_corr = True

# %%
def get_corr(df, method="spearman"):
    return df[[col for col in df.columns if "item" in col]].corr(method=method).abs()


corr_df = None
if filter_by_corr:
    corr_df = get_corr(feature_df, method="spearman")

root_output_folder = f"top_{top_n}_features_filtered"
os.makedirs(root_output_folder, exist_ok=True)

# %%
for result_folder in (pbar_outer := tqdm(results_paths)):
    folder_name = os.path.basename(result_folder)
    feature_set_name = folder_name.split("_", 1)[1]
    output_folder = os.path.join(root_output_folder, feature_set_name)
    os.makedirs(output_folder, exist_ok=True)

    pbar_outer.set_description(f"Processing feature set '{feature_set_name}'")
    pat = os.path.join(result_folder, "*_merged.csv")
    result_paths = glob(pat)

    for result_path in (pbar_inner := tqdm(result_paths)):
        result_file_name = os.path.basename(result_path)
        pesticide_name = result_file_name.split("_")[0]

        pbar_inner.set_description(f"Processing {result_file_name}")

        top_feat_codes = get_top_n_feature_info(
            output_folder,
            result_path,
            pesticide_name,
            top_n=top_n,
            filter_by_corr=filter_by_corr,
            corr_df=corr_df,
            corr_threshold=corr_threshold,
        )

        get_top_n_features(output_folder, pesticide_name, top_feat_codes)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/321 [00:00<?, ?it/s]
# Filtering item020078 (SIC-Sugarcane & sugar beets; Irish potatoes; field crops, exceptcash grains, n.e.c. (0133, 0134, 0139), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item120027 (Oats, ($1,000), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item130112 (Soybeans for beans-Irrigated (acres), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item310189 (Pears, Harvested (pounds), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item260005 (Corn for grain or seed, Irrigated (acres), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item010082 (Cotton (acres), 1992)
# Keeping 2730/2781 (98.2%) features
# (2730, 6)
# Filtering item090040 (Manufactured in the last five years--Cotton pickers & strippers,(numbers), 1992)
# Keeping 2730/2781 (98.2%) features
# (2730, 6)
# Filtering item310343 (Pecans (in shell), Total (farms), 1992)
# Keeping 2725/2781 (98.0%) features
# (2725, 6)
# Filtering item020003 (Total sales, average per farm, (dollars), 1992)
# Keeping 2719/2781 (97.8%) features
# (2719, 6)
# Filtering item290185 (Turnips, Harvested (farms), 1992)
# Keeping 2719/2781 (97.8%) features
# (2719, 6)
# Filtering item010070 (Barley for grain (acres), 1992)
# Keeping 2744/2781 (98.7%) features
# (2744, 6)
# Filtering item260042 (Barley for grain, Harvested (acres), 1992)
# Keeping 2742/2781 (98.6%) features
# (2742, 6)
# Filtering item090003 (Estimated market value of all machinery & equipment, averageper farm (dollars), 1992)
# Keeping 2740/2781 (98.5%) features
# (2740, 6)
# Filtering item260020 (Spring wheat for grain, Irrigated (acres), 1992)
# Keeping 2740/2781 (98.5%) features
# (2740, 6)
# Filtering item130125 (Dry edible beans excluding dry limas, 100 to 249 acres, 1992)
# Keeping 2738/2781 (98.5%) features
# (2738, 6)
# Filtering item130054 (Barley for grain-500 acres or more, 1992)
# Keeping 2738/2781 (98.5%) features
# (2738, 6)
# Filtering item130140 (Sugar beets for sugar, (acres), 1992)
# Keeping 2733/2781 (98.3%) features
# (2733, 6)
# Filtering item130147 (Sugar beets for sugar-250 to 499 acres, 1992)
# Keeping 2733/2781 (98.3%) features
# (2733, 6)
# Filtering item120024 (Barley, (farms), 1992)
# Keeping 2732/2781 (98.2%) features
# (2732, 6)
# Filtering item130053 (Barley for grain-250 to 499 acres, 1992)
# Keeping 2732/2781 (98.2%) features
# (2732, 6)
# Filtering item050025 (Farms with 10 workers or more - 150 days or more (workers), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item010031 (Total farm production expenses, average per farm (dollars), 1992)
# Keeping 2744/2781 (98.7%) features
# (2744, 6)
# Filtering item010039 (Cattle & calves inventory (farms), 1992)
# Keeping 2702/2781 (97.2%) features
# (2702, 6)
# Filtering item290119 (Lettuce & Romaine, Irrigated (farms), 1992)
# Keeping 2701/2781 (97.1%) features
# (2701, 6)
# Filtering item090058 (Manufactured more than five years ago--Mower conditioners,(numbers), 1992)
# Keeping 2695/2781 (96.9%) features
# (2695, 6)
# Filtering item290006 (Vegetables harvested (see text), Harvested(acres), 1992)
# Keeping 2691/2781 (96.8%) features
# (2691, 6)
# Filtering item140131 (Cattle sold, 100-199 (number), 1992)
# Keeping 2690/2781 (96.7%) features
# (2690, 6)
# Filtering item130189 (Vegetables harvested for sale (see text) (acres), 1992)
# Keeping 2684/2781 (96.5%) features
# (2684, 6)
# Filtering item010048 (Hogs & pigs inventory (number), 1992)
# Keeping 2658/2781 (95.6%) features
# (2658, 6)
# Filtering item090010 (Farm value group-$100,000 to $199,999, 1992)
# Keeping 2624/2781 (94.4%) features
# (2624, 6)
# Filtering item130207 (Land in orchards-500.0 acres or more, 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item300002 (Land in orchards, Total (acres), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item020055 (Fruits, nuts, & berries, ($1,000), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item310240 (Grapefruit, Trees or vines of bearing age (farms), 1992)
# Keeping 2742/2781 (98.6%) features
# (2742, 6)
# Filtering item300004 (Land in orchards, Irrigated (acres), 1992)
# Keeping 2742/2781 (98.6%) features
# (2742, 6)
# Filtering item130199 (Land in orchards, (acres), 1992)
# Keeping 2736/2781 (98.4%) features
# (2736, 6)
# Filtering item040006 (Farms with net gains, average per farm (dollars), 1992)
# Keeping 2731/2781 (98.2%) features
# (2731, 6)
# Filtering item310241 (Grapefruit, Trees or vines of bearing age (number), 1992)
# Keeping 2730/2781 (98.2%) features
# (2730, 6)
# Filtering item310273 (Oranges, Total (trees or vines), 1992)
# Keeping 2719/2781 (97.8%) features
# (2719, 6)
# Filtering item120282 (Land in orchards, (acres), 1992)
# Keeping 2719/2781 (97.8%) features
# (2719, 6)
# Filtering item130138 (Irish potatoes-500.0 acres or more, 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item270043 (Irish potatoes, Harvested (cwt), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item010095 (Irish potatoes (cwt), 1992)
# Keeping 2746/2781 (98.7%) features
# (2746, 6)
# Filtering item130130 (Irish potatoes, (cwt), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item060076 (Land under Federal acreage reduction programs-- ConservationReserve or Wetlands Reserve Programs (farms), 1992)
# Keeping 2739/2781 (98.5%) features
# (2739, 6)
# Filtering item040017 (Gross before taxes & expenses ($1,000), 1992)
# Keeping 2739/2781 (98.5%) features
# (2739, 6)
# Filtering item110008 (Full owners-harvested crop land (acres), 1992)
# Keeping 2729/2781 (98.1%) features
# (2729, 6)
# Filtering item040009 (Farms with net losses, average per farm (dollars), 1992)
# Keeping 2729/2781 (98.1%) features
# (2729, 6)
# Filtering item270041 (Irish potatoes, Harvested (farms), 1992)
# Keeping 2729/2781 (98.1%) features
# (2729, 6)
# Filtering item140103 (Calves sold, (number), 1992)
# Keeping 2726/2781 (98.0%) features
# (2726, 6)
# Filtering item030015 (Agricultural chemicals, ($1,000), 1992)
# Keeping 2736/2781 (98.4%) features
# (2736, 6)
# Filtering item120099 (Farms with net losses, ($1,000), 1992)
# Keeping 2735/2781 (98.3%) features
# (2735, 6)
# Filtering item130205 (Land in orchards-100.0 to 249.9 acres, 1992)
# Keeping 2735/2781 (98.3%) features
# (2735, 6)
# Filtering item030039 (Interest-Secured by real estate ($1,000), 1992)
# Keeping 2694/2781 (96.9%) features
# (2694, 6)
# Filtering item050042 (Reported only workers working less than 150 days (workers), 1992)
# Keeping 2692/2781 (96.8%) features
# (2692, 6)
# Filtering item080024 (Irrigated acres by size of farm: 140-179 acres, (farms), 1992)
# Keeping 2692/2781 (96.8%) features
# (2692, 6)
# Filtering item030035 (Customwork, machine hire, & rental of machinery & equipment($1,000), 1992)
# Keeping 2690/2781 (96.7%) features
# (2690, 6)
# Filtering item070006 (Harvested crop land by size of farm: 10-49 acres (acres harvested), 1992)
# Keeping 2686/2781 (96.6%) features
# (2686, 6)
# Filtering item050046 (Reported both - workers working 150 days or more & workersworking less than 150 days (less than 150 days), 1992)
# Keeping 2685/2781 (96.5%) features
# (2685, 6)
# Filtering item060005 (Estimated market value of land & buildings ($1,000), 1992)
# Keeping 2684/2781 (96.5%) features
# (2684, 6)
# Filtering item040034 (CCC Loan-Wheat, (farms), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item130147 (Sugar beets for sugar-250 to 499 acres, 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item130148 (Sugar beets for sugar-500 acres or more, 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item120266 (Sugar beets for sugar, (tons), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item020045 (Other grains, ($1,000), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item270016 (Dry edible beans excluding dry limas, Harvested (farms), 1992)
# Keeping 2743/2781 (98.6%) features
# (2743, 6)
# Filtering item260073 (Flaxseed, Harvested (bu.), 1992)
# Keeping 2741/2781 (98.6%) features
# (2741, 6)
# Filtering item270057 (Sugar beets for sugar, Harvested (acres), 1992)
# Keeping 2739/2781 (98.5%) features
# (2739, 6)
# Filtering item070042 (Harvested crop land by acres harvested: 500-999 acres (acres), 1992)
# Keeping 2716/2781 (97.7%) features
# (2716, 6)
# Filtering item120258 (Dry edible beans excluding dry limas, (farms), 1992)
# Keeping 2714/2781 (97.6%) features
# (2714, 6)
# Filtering item010058 (Corn for grain or seed (acres), 1992)
# Keeping 2731/2781 (98.2%) features
# (2731, 6)
# Filtering item120087 (Cash rent ($1,000), 1992)
# Keeping 2730/2781 (98.2%) features
# (2730, 6)
# Filtering item120135 (Tenure-Tenants, (acres), 1992)
# Keeping 2729/2781 (98.1%) features
# (2729, 6)
# Filtering item110018 (Tenants-harvested crop land (acres), 1992)
# Keeping 2713/2781 (97.6%) features
# (2713, 6)
# Filtering item130115 (Soybeans for beans-100 to 249 acres, 1992)
# Keeping 2698/2781 (97.0%) features
# (2698, 6)
# Filtering item060074 (Land under Federal acreage reduction programs--Diverted underannual commodity programs, (farms), 1992)
# Keeping 2679/2781 (96.3%) features
# (2679, 6)
# Filtering item130040 (Wheat for grain-1 to 24 acres, 1992)
# Keeping 2679/2781 (96.3%) features
# (2679, 6)
# Filtering item060014 (Value group--$500,000 to $999,999, 1992)
# Keeping 2678/2781 (96.3%) features
# (2678, 6)
# Filtering item130117 (Soybeans for beans-500 acres or more, 1992)
# Keeping 2678/2781 (96.3%) features
# (2678, 6)
# Filtering item110017 (Tenants-harvested crop land (farms), 1992)
# Keeping 2662/2781 (95.7%) features
# (2662, 6)
# Filtering item120282 (Land in orchards, (acres), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item100012 (Sprays, dusts, granules, fumigants, etc., to control--diseasesin crops & orchards (acres on which used), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item300002 (Land in orchards, Total (acres), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item100016 (Chemicals used for defoliation or for growth control of cropsor thinning of fruit (acres on which used), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item120079 (Contract labor ($1,000), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item310009 (Apples, Harvested (pounds), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item080020 (Irrigated acres by size of farm: 70-99 acres, (farms), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item310002 (Apples, Total (acres), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item130206 (Land in orchards-250.0 to 499.9 acres, 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item300003 (Land in orchards, Irrigated (farms), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item120083 (Customwork, machine hire, & rental of machinery & equipment,($1,000), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item100008 (Sprays, dusts, granules, fumigants, etc., to control--insectson hay & other crops (acres on which used), 1992)
# Keeping 2744/2781 (98.7%) features
# (2744, 6)
# Filtering item030017 (Petroleum products, ($1,000), 1992)
# Keeping 2701/2781 (97.1%) features
# (2701, 6)
# Filtering item090055 (Manufactured more than five years ago--Cotton pickers andstrippers, (farms), 1992)
# Keeping 2699/2781 (97.1%) features
# (2699, 6)
# Filtering item090056 (Manufactured more than five years ago--Cotton pickers andstrippers, (numbers), 1992)
# Keeping 2699/2781 (97.1%) features
# (2699, 6)
# Filtering item090012 (Farm value group-$500,000 or more, 1992)
# Keeping 2699/2781 (97.1%) features
# (2699, 6)
# Filtering item260114 (Sunflower seeds, Irrigated (farms), 1992)
# Keeping 2699/2781 (97.1%) features
# (2699, 6)
# Filtering item120069 (Commercial fertilizer ($1,000), 1992)
# Keeping 2695/2781 (96.9%) features
# (2695, 6)
# Filtering item130093 (Cotton-250 to 499 acres, 1992)
# Keeping 2691/2781 (96.8%) features
# (2691, 6)
# Filtering item080034 (Irrigated acres by size of farm: 1,000-1,999 acres, (farms), 1992)
# Keeping 2691/2781 (96.8%) features
# (2691, 6)
# Filtering item290058 (Cauliflower, Harvested (acres), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item290060 (Cauliflower, Irrigated (acres), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item290059 (Cauliflower, Irrigated (farms), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item120037 (Vegetables, sweet corn, & melons($1,000), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item060017 (Value group--$5,000,000 or more, 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item020053 (Vegetables, sweet corn, & melons ($1,000), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item310254 (Lemons, Total (acres), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item290119 (Lettuce & Romaine, Irrigated (farms), 1992)
# Keeping 2746/2781 (98.7%) features
# (2746, 6)
# Filtering item290032 (Broccoli, Irrigated (acres), 1992)
# Keeping 2746/2781 (98.7%) features
# (2746, 6)
# Filtering item290030 (Broccoli, Harvested (acres), 1992)
# Keeping 2746/2781 (98.7%) features
# (2746, 6)
# Filtering item130043 (Wheat for grain-250 to 499 acres, 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item130127 (Dry edible beans excluding dry limas, >= 500 acres, 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item060056 (Crop land in cultivated summer fallow, (farms), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item070024 (Harvested crop land by size of farm: 1,000-1,999 ac (acresharvested), 1992)
# Keeping 2726/2781 (98.0%) features
# (2726, 6)
# Filtering item040034 (CCC Loan-Wheat, (farms), 1992)
# Keeping 2726/2781 (98.0%) features
# (2726, 6)
# Filtering item130042 (Wheat for grain-100 to 249 acres, 1992)
# Keeping 2717/2781 (97.7%) features
# (2717, 6)
# Filtering item130064 (Oats for grain-500 acres or more, 1992)
# Keeping 2717/2781 (97.7%) features
# (2717, 6)
# Filtering item130044 (Wheat for grain-500 acres or more, 1992)
# Keeping 2717/2781 (97.7%) features
# (2717, 6)
# Filtering item040013 (Gov payments-CRP & WRP, (farms), 1992)
# Keeping 2712/2781 (97.5%) features
# (2712, 6)
# Filtering item260022 (Durum wheat for grain, Harvested (acres), 1992)
# Keeping 2710/2781 (97.4%) features
# (2710, 6)
# Filtering item060073 (Pastureland, all types (acres), 1992)
# Keeping 2746/2781 (98.7%) features
# (2746, 6)
# Filtering item130044 (Wheat for grain-500 acres or more, 1992)
# Keeping 2746/2781 (98.7%) features
# (2746, 6)
# Filtering item260012 (Wheat for grain, Harvested (acres), 1992)
# Keeping 2733/2781 (98.3%) features
# (2733, 6)
# Filtering item120235 (Wheat for grain, (acres), 1992)
# Keeping 2732/2781 (98.2%) features
# (2732, 6)
# Filtering item110010 (Part owners, (acres), 1992)
# Keeping 2721/2781 (97.8%) features
# (2721, 6)
# Filtering item280158 (Corn for silage/green chop Harvested(tons green), 1992)
# Keeping 2719/2781 (97.8%) features
# (2719, 6)
# Filtering item110045 (Operators by age group-70 yrs & over, 1992)
# Keeping 2684/2781 (96.5%) features
# (2684, 6)
# Filtering item120118 (Farms by size-2,000 acres or more, 1992)
# Keeping 2681/2781 (96.4%) features
# (2681, 6)
# Filtering item040034 (CCC Loan-Wheat, (farms), 1992)
# Keeping 2681/2781 (96.4%) features
# (2681, 6)
# Filtering item140105 (Calves sold, 1-9 (farms), 1992)
# Keeping 2666/2781 (95.9%) features
# (2666, 6)
# Filtering item090040 (Manufactured in the last five years--Cotton pickers & strippers,(numbers), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item090039 (Manufactured in the last five years--Cotton pickers & strippers,(farms), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item020047 (Cotton & cottonseed, ($1,000), 1992)
# Keeping 2738/2781 (98.5%) features
# (2738, 6)
# Filtering item040041 (CCC Loan-Cotton,($1,000), 1992)
# Keeping 2738/2781 (98.5%) features
# (2738, 6)
# Filtering item350001 (Black & other races, Land in farms (farms), 1992)
# Keeping 2735/2781 (98.3%) features
# (2735, 6)
# Filtering item060063 (Woodland pastured, (acres), 1992)
# Keeping 2735/2781 (98.3%) features
# (2735, 6)
# Filtering item110046 (Operators by age group-Average age, 1992)
# Keeping 2735/2781 (98.3%) features
# (2735, 6)
# Filtering item270005 (Cotton, Irrigated (acres), 1992)
# Keeping 2734/2781 (98.3%) features
# (2734, 6)
# Filtering item130115 (Soybeans for beans-100 to 249 acres, 1992)
# Keeping 2719/2781 (97.8%) features
# (2719, 6)
# Filtering item120234 (Wheat for grain, (farms), 1992)
# Keeping 2706/2781 (97.3%) features
# (2706, 6)
# Filtering item310207 (Plums & Prunes (see text) (fresh weight), Harvested (pounds), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item260098 (Rice, Harvested (cwt), 1992)
# Keeping 2739/2781 (98.5%) features
# (2739, 6)
# Filtering item120029 (Other grains, ($1,000), 1992)
# Keeping 2739/2781 (98.5%) features
# (2739, 6)
# Filtering item040045 (CCC Loan-Peanuts, rye, rice, tobacco, & honey ($1,000), 1992)
# Keeping 2739/2781 (98.5%) features
# (2739, 6)
# Filtering item020045 (Other grains, ($1,000), 1992)
# Keeping 2739/2781 (98.5%) features
# (2739, 6)
# Filtering item130207 (Land in orchards-500.0 acres or more, 1992)
# Keeping 2739/2781 (98.5%) features
# (2739, 6)
# Filtering item120245 (Rice, (cwt), 1992)
# Keeping 2738/2781 (98.5%) features
# (2738, 6)
# Filtering item040044 (CCC Loan-Peanuts, rye, rice, tobacco, & honey (farms), 1992)
# Keeping 2738/2781 (98.5%) features
# (2738, 6)
# Filtering item310200 (Plums & Prunes (see text) (fresh weight), Total (acres), 1992)
# Keeping 2738/2781 (98.5%) features
# (2738, 6)
# Filtering item140086 (Cattle & calves sold, (number), 1992)
# Keeping 2718/2781 (97.7%) features
# (2718, 6)
# Filtering item280008 (Alfalfa seed, Harvested (pounds), 1992)
# Keeping 2746/2781 (98.7%) features
# (2746, 6)
# Filtering item290015 (Asparagus, Irrigated (farms), 1992)
# Keeping 2746/2781 (98.7%) features
# (2746, 6)
# Filtering item310144 (Nectarines, Harvested (pounds), 1992)
# Keeping 2746/2781 (98.7%) features
# (2746, 6)
# Filtering item280010 (Alfalfa seed, Irrigated (acres), 1992)
# Keeping 2746/2781 (98.7%) features
# (2746, 6)
# Filtering item220003 (Colonies of bees & honey sales (farms), 1992)
# Keeping 2746/2781 (98.7%) features
# (2746, 6)
# Filtering item310366 (English walnuts (in shell), Trees or vines of bearing age (farms),)
# Keeping 2741/2781 (98.6%) features
# (2741, 6)
# Filtering item310143 (Nectarines, Harvested (farms), 1992)
# Keeping 2738/2781 (98.5%) features
# (2738, 6)
# Filtering item060074 (Land under Federal acreage reduction programs--Diverted underannual commodity programs, (farms), 1992)
# Keeping 2710/2781 (97.4%) features
# (2710, 6)
# Filtering item010033 (Net cash return from agricultural sales for the farm unit (seetext), ($1,000), 1992)
# Keeping 2697/2781 (97.0%) features
# (2697, 6)
# Filtering item140121 (Cattle sold, ($1,000), 1992)
# Keeping 2681/2781 (96.4%) features
# (2681, 6)
# Filtering item080019 (Irrigated acres by size of farm: 50-69 acres, (acres irrigated), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item310182 (Pears, Total (acres), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item100015 (Chemicals used for defoliation or for growth control of cropsor thinning of fruit (farms), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item310186 (Pears, Trees or vines of bearing age (farms), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item310189 (Pears, Harvested (pounds), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item100016 (Chemicals used for defoliation or for growth control of cropsor thinning of fruit (acres on which used), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item120039 (Fruits, nuts, & berries, ($1,000), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item310185 (Pears, Trees or vines not of bearing age (number), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item300004 (Land in orchards, Irrigated (acres), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item020055 (Fruits, nuts, & berries, ($1,000), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item040041 (CCC Loan-Cotton,($1,000), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item040031 (CCC Loan-Total ($1,000), 1992)
# Keeping 2746/2781 (98.7%) features
# (2746, 6)
# Filtering item100016 (Chemicals used for defoliation or for growth control of cropsor thinning of fruit (acres on which used), 1992)
# Keeping 2746/2781 (98.7%) features
# (2746, 6)
# Filtering item040040 (CCC Loan-Cotton, (farms), 1992)
# Keeping 2741/2781 (98.6%) features
# (2741, 6)
# Filtering item120071 (Agricultural chemicals ($1,000), 1992)
# Keeping 2730/2781 (98.2%) features
# (2730, 6)
# Filtering item120176 (SIC-Sugarcane & sugar beets; Irish potatoes; field crops, exceptcash grains, n.e.c. (0133, 0134, 0139), 1992)
# Keeping 2730/2781 (98.2%) features
# (2730, 6)
# Filtering item120031 (Cotton & cottonseed, ($1,000), 1992)
# Keeping 2728/2781 (98.1%) features
# (2728, 6)
# Filtering item020076 (SIC-Cotton (0131), 1992)
# Keeping 2720/2781 (97.8%) features
# (2720, 6)
# Filtering item070026 (Harvested crop land by size of farm:>=2,000 acres (acresharvested), 1992)
# Keeping 2719/2781 (97.8%) features
# (2719, 6)
# Filtering item160026 (Any poultry sold, (farms), 1992)
# Keeping 2718/2781 (97.7%) features
# (2718, 6)
# Filtering item370001 (Black, All farms (farms), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item280132 (Alfalfa hay, Harvested (acres), 1992)
# Keeping 2746/2781 (98.7%) features
# (2746, 6)
# Filtering item290077 (Green cowpeas & green southern peas, Harvested (farms), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item370004 (Black, Farms with sales of $10,000 or more (land in farms), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item290202 (Watermelons, Harvested (acres), 1992)
# Keeping 2744/2781 (98.7%) features
# (2744, 6)
# Filtering item270001 (Cotton, Harvested (farms), 1992)
# Keeping 2732/2781 (98.2%) features
# (2732, 6)
# Filtering item120031 (Cotton & cottonseed, ($1,000), 1992)
# Keeping 2730/2781 (98.2%) features
# (2730, 6)
# Filtering item310350 (Pecans (in shell), Harvested (farms), 1992)
# Keeping 2728/2781 (98.1%) features
# (2728, 6)
# Filtering item130094 (Cotton-500 acres or more, 1992)
# Keeping 2728/2781 (98.1%) features
# (2728, 6)
# Filtering item140125 (Cattle sold, 10-19 (number), 1992)
# Keeping 2727/2781 (98.1%) features
# (2727, 6)
# Filtering item130043 (Wheat for grain-250 to 499 acres, 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item120019 (Wheat, ($1,000), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item130042 (Wheat for grain-100 to 249 acres, 1992)
# Keeping 2739/2781 (98.5%) features
# (2739, 6)
# Filtering item130044 (Wheat for grain-500 acres or more, 1992)
# Keeping 2739/2781 (98.5%) features
# (2739, 6)
# Filtering item120117 (Farms by size-1,000 to 1,999 acres, 1992)
# Keeping 2733/2781 (98.3%) features
# (2733, 6)
# Filtering item140078 (Steers, steer calves, bulls, & bull calves inventory 100-199(number), 1992)
# Keeping 2733/2781 (98.3%) features
# (2733, 6)
# Filtering item340062 (Mung beans for beans, Harvested (acres), 1992)
# Keeping 2731/2781 (98.2%) features
# (2731, 6)
# Filtering item290022 (Snap beans, Harvested (acres), 1992)
# Keeping 2731/2781 (98.2%) features
# (2731, 6)
# Filtering item120100 (Farms with losses average per farm, (dollars), 1992)
# Keeping 2731/2781 (98.2%) features
# (2731, 6)
# Filtering item080002 (Land in irrigated farms, (acres), 1992)
# Keeping 2729/2781 (98.1%) features
# (2729, 6)
# Filtering item120069 (Commercial fertilizer ($1,000), 1992)
# Keeping 2738/2781 (98.5%) features
# (2738, 6)
# Filtering item190006 (Goat milk-sales (gallons), 1992)
# Keeping 2738/2781 (98.5%) features
# (2738, 6)
# Filtering item040041 (CCC Loan-Cotton,($1,000), 1992)
# Keeping 2738/2781 (98.5%) features
# (2738, 6)
# Filtering item100016 (Chemicals used for defoliation or for growth control of cropsor thinning of fruit (acres on which used), 1992)
# Keeping 2738/2781 (98.5%) features
# (2738, 6)
# Filtering item130014 (Corn for grain or seed, 500 acres or more, 1992)
# Keeping 2737/2781 (98.4%) features
# (2737, 6)
# Filtering item030033 (Repair & maintenance, ($1,000), 1992)
# Keeping 2687/2781 (96.6%) features
# (2687, 6)
# Filtering item020033 (Corn for grain, ($1,000), 1992)
# Keeping 2677/2781 (96.3%) features
# (2677, 6)
# Filtering item120031 (Cotton & cottonseed, ($1,000), 1992)
# Keeping 2675/2781 (96.2%) features
# (2675, 6)
# Filtering item100004 (Crop land fertilized excluding pastureland (acres used), 1992)
# Keeping 2675/2781 (96.2%) features
# (2675, 6)
# Filtering item310120 (Kiwifruit, Total (trees or vines), 1992)
# Keeping 2671/2781 (96.0%) features
# (2671, 6)
# Filtering item100014 (Sprays, dusts, granules, fumigants, etc., to control--weeds,grass or brush in crops & pasture (acres on which used), 1992)
# Keeping 2722/2781 (97.9%) features
# (2722, 6)
# Filtering item060051 (Other crop land, (acres), 1992)
# Keeping 2722/2781 (97.9%) features
# (2722, 6)
# Filtering item260033 (Winter wheat for grain, Harvested (bu), 1992)
# Keeping 2720/2781 (97.8%) features
# (2720, 6)
# Filtering item040039 (CCC Loan-Sorghum, barley & oats,($1,000), 1992)
# Keeping 2720/2781 (97.8%) features
# (2720, 6)
# Filtering item020039 (Sorghum for grain, ($1,000), 1992)
# Keeping 2720/2781 (97.8%) features
# (2720, 6)
# Filtering item270027 (Dry edible peas, Harvested (acres), 1992)
# Keeping 2718/2781 (97.7%) features
# (2718, 6)
# Filtering item130034 (Sorghum for grain or seed, 500 acres or more, 1992)
# Keeping 2718/2781 (97.7%) features
# (2718, 6)
# Filtering item260051 (Canola & other rapeseed, Harvested(farms), 1992)
# Keeping 2716/2781 (97.7%) features
# (2716, 6)
# Filtering item060057 (Crop land in cultivated summer fallow, (acres), 1992)
# Keeping 2716/2781 (97.7%) features
# (2716, 6)
# Filtering item040038 (CCC Loan-Sorghum, barley & oats,(farms), 1992)
# Keeping 2716/2781 (97.7%) features
# (2716, 6)
# Filtering item070044 (Harvested crop land by acres harvested:>=1,000 acres (acres), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item120005 (Total crop land, (acres), 1992)
# Keeping 2715/2781 (97.6%) features
# (2715, 6)
# Filtering item040035 (CCC Loan-Wheat, ($1,000), 1992)
# Keeping 2715/2781 (97.6%) features
# (2715, 6)
# Filtering item070026 (Harvested crop land by size of farm:>=2,000 acres (acresharvested), 1992)
# Keeping 2714/2781 (97.6%) features
# (2714, 6)
# Filtering item260042 (Barley for grain, Harvested (acres), 1992)
# Keeping 2712/2781 (97.5%) features
# (2712, 6)
# Filtering item010070 (Barley for grain (acres), 1992)
# Keeping 2708/2781 (97.4%) features
# (2708, 6)
# Filtering item130052 (Barley for grain-100 to 249 acres, 1992)
# Keeping 2708/2781 (97.4%) features
# (2708, 6)
# Filtering item120019 (Wheat, ($1,000), 1992)
# Keeping 2708/2781 (97.4%) features
# (2708, 6)
# Filtering item390004 (Grazing permits, Farms by land in farms (100 to 259 acres), 1992)
# Keeping 2708/2781 (97.4%) features
# (2708, 6)
# Filtering item260051 (Canola & other rapeseed, Harvested(farms), 1992)
# Keeping 2706/2781 (97.3%) features
# (2706, 6)
# Filtering item130070 (Rice-1 to 24 acres, 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item130073 (Rice-250 to 499 acres, 1992)
# Keeping 2738/2781 (98.5%) features
# (2738, 6)
# Filtering item120129 (Grain & bean combines (number), 1992)
# Keeping 2732/2781 (98.2%) features
# (2732, 6)
# Filtering item130071 (Rice-25 to 99 acres, 1992)
# Keeping 2732/2781 (98.2%) features
# (2732, 6)
# Filtering item120244 (Rice, (acres), 1992)
# Keeping 2731/2781 (98.2%) features
# (2731, 6)
# Filtering item130074 (Rice-500 acres or more, 1992)
# Keeping 2731/2781 (98.2%) features
# (2731, 6)
# Filtering item090054 (Manufactured more than five years ago--Grain & bean combines,(numbers), 1992)
# Keeping 2731/2781 (98.2%) features
# (2731, 6)
# Filtering item140103 (Calves sold, (number), 1992)
# Keeping 2728/2781 (98.1%) features
# (2728, 6)
# Filtering item110014 (Part owners-harvested crop land (acres), 1992)
# Keeping 2699/2781 (97.1%) features
# (2699, 6)
# Filtering item290133 (Okra, Harvested (farms), 1992)
# Keeping 2699/2781 (97.1%) features
# (2699, 6)
# Filtering item060051 (Other crop land, (acres), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item060057 (Crop land in cultivated summer fallow, (acres), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item060077 (Land under Federal acreage reduction programs-- ConservationReserve or Wetlands Reserve Programs, (acres), 1992)
# Keeping 2743/2781 (98.6%) features
# (2743, 6)
# Filtering item260032 (Winter wheat for grain, Harvested (acres), 1992)
# Keeping 2741/2781 (98.6%) features
# (2741, 6)
# Filtering item060053 (Crop land in cover crops, legumes, & soil-improvement grasses,not harvested & not pastured, (acres), 1992)
# Keeping 2741/2781 (98.6%) features
# (2741, 6)
# Filtering item060003 (Average size of farm, (acres), 1992)
# Keeping 2739/2781 (98.5%) features
# (2739, 6)
# Filtering item120091 (All other farm production exp ($1,000), 1992)
# Keeping 2720/2781 (97.8%) features
# (2720, 6)
# Filtering item310301 (Other Tangerines, Trees or vines not of bearing age (farms), 1992)
# Keeping 2717/2781 (97.7%) features
# (2717, 6)
# Filtering item310145 (Olives, Total (farms), 1992)
# Keeping 2713/2781 (97.6%) features
# (2713, 6)
# Filtering item120235 (Wheat for grain, (acres), 1992)
# Keeping 2708/2781 (97.4%) features
# (2708, 6)
# Filtering item070015 (Harvested crop land by size of farm: 180-219 acres (farms), 1992)
# Keeping 2735/2781 (98.3%) features
# (2735, 6)
# Filtering item260081 (Oats for grain, Harvested (farms), 1992)
# Keeping 2731/2781 (98.2%) features
# (2731, 6)
# Filtering item140135 (Cattle sold, >= 500 (number), 1992)
# Keeping 2730/2781 (98.2%) features
# (2730, 6)
# Filtering item120277 (Hay-alfalfa, other tame, small grain, wild, grass silage, greenchop, etc. (see text), (acres), 1992)
# Keeping 2722/2781 (97.9%) features
# (2722, 6)
# Filtering item120222 (Hens & pullets laying age inv (number), 1992)
# Keeping 2722/2781 (97.9%) features
# (2722, 6)
# Filtering item170007 (Sheep & lamb inventory 100-299 (farms), 1992)
# Keeping 2722/2781 (97.9%) features
# (2722, 6)
# Filtering item110010 (Part owners, (acres), 1992)
# Keeping 2711/2781 (97.5%) features
# (2711, 6)
# Filtering item140121 (Cattle sold, ($1,000), 1992)
# Keeping 2695/2781 (96.9%) features
# (2695, 6)
# Filtering item090047 (Manufactured in the last five years--Wheel tractors, (farms), 1992)
# Keeping 2582/2781 (92.8%) features
# (2582, 6)
# Filtering item040045 (CCC Loan-Peanuts, rye, rice, tobacco, & honey ($1,000), 1992)
# Keeping 2582/2781 (92.8%) features
# (2582, 6)
# Filtering item310232 (All Citrus Fruit, Trees or vines of bearing age (number), 1992)
# Keeping 2741/2781 (98.6%) features
# (2741, 6)
# Filtering item300002 (Land in orchards, Total (acres), 1992)
# Keeping 2740/2781 (98.5%) features
# (2740, 6)
# Filtering item310281 (Tangelos, Total (acres), 1992)
# Keeping 2736/2781 (98.4%) features
# (2736, 6)
# Filtering item300004 (Land in orchards, Irrigated (acres), 1992)
# Keeping 2736/2781 (98.4%) features
# (2736, 6)
# Filtering item310306 (Other tangerines, Harvested (pounds), 1992)
# Keeping 2736/2781 (98.4%) features
# (2736, 6)
# Filtering item310243 (Grapefruit, Harvested (pounds), 1992)
# Keeping 2734/2781 (98.3%) features
# (2734, 6)
# Filtering item310288 (Tangelos, Harvested (pounds), 1992)
# Keeping 2734/2781 (98.3%) features
# (2734, 6)
# Filtering item310286 (Tangelos, Trees or vines of bearing age (number), 1992)
# Keeping 2734/2781 (98.3%) features
# (2734, 6)
# Filtering item120039 (Fruits, nuts, & berries, ($1,000), 1992)
# Keeping 2734/2781 (98.3%) features
# (2734, 6)
# Filtering item130199 (Land in orchards, (acres), 1992)
# Keeping 2728/2781 (98.1%) features
# (2728, 6)
# Filtering item310275 (Oranges, Trees or vines not of bearing age (number), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item030041 (Int-Not secured by real estate ($1,000), 1992)
# Keeping 2717/2781 (97.7%) features
# (2717, 6)
# Filtering item130088 (Cotton-Irrigated, (farms), 1992)
# Keeping 2716/2781 (97.7%) features
# (2716, 6)
# Filtering item310225 (Other noncitrus fruit, Harvested (lb), 1992)
# Keeping 2716/2781 (97.7%) features
# (2716, 6)
# Filtering item060066 (Other land, (farms), 1992)
# Keeping 2624/2781 (94.4%) features
# (2624, 6)
# Filtering item060050 (Other crop land, (farms), 1992)
# Keeping 2609/2781 (93.8%) features
# (2609, 6)
# Filtering item310276 (Oranges, Trees or vines of bearing age (farms), 1992)
# Keeping 2599/2781 (93.5%) features
# (2599, 6)
# Filtering item310026 (Avocados, Harvested (farms), 1992)
# Keeping 2596/2781 (93.3%) features
# (2596, 6)
# Filtering item040008 (Farms with net losses, ($1,000), 1992)
# Keeping 2596/2781 (93.3%) features
# (2596, 6)
# Filtering item110060 (Other-cooperative, estate or trust, institutional, etc. (acres), 1992)
# Keeping 2596/2781 (93.3%) features
# (2596, 6)
# Filtering item120236 (Wheat for grain, (bu.), 1992)
# Keeping 2743/2781 (98.6%) features
# (2743, 6)
# Filtering item060056 (Crop land in cultivated summer fallow, (farms), 1992)
# Keeping 2743/2781 (98.6%) features
# (2743, 6)
# Filtering item020035 (Wheat, ($1,000), 1992)
# Keeping 2738/2781 (98.5%) features
# (2738, 6)
# Filtering item040035 (CCC Loan-Wheat, ($1,000), 1992)
# Keeping 2738/2781 (98.5%) features
# (2738, 6)
# Filtering item130044 (Wheat for grain-500 acres or more, 1992)
# Keeping 2738/2781 (98.5%) features
# (2738, 6)
# Filtering item120019 (Wheat, ($1,000), 1992)
# Keeping 2738/2781 (98.5%) features
# (2738, 6)
# Filtering item100002 (Commercial fertilizer, (acres used), 1992)
# Keeping 2712/2781 (97.5%) features
# (2712, 6)
# Filtering item130053 (Barley for grain-250 to 499 acres, 1992)
# Keeping 2712/2781 (97.5%) features
# (2712, 6)
# Filtering item130052 (Barley for grain-100 to 249 acres, 1992)
# Keeping 2710/2781 (97.4%) features
# (2710, 6)
# Filtering item120083 (Customwork, machine hire, & rental of machinery & equipment,($1,000), 1992)
# Keeping 2709/2781 (97.4%) features
# (2709, 6)
# Filtering item310187 (Pears, Trees or vines of bearing age (number), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item310189 (Pears, Harvested (pounds), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item310183 (Pears, Total (trees or vines), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item310182 (Pears, Total (acres), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item350002 (Black & other races, Land in farms (acres), 1992)
# Keeping 2746/2781 (98.7%) features
# (2746, 6)
# Filtering item310366 (English walnuts (in shell), Trees or vines of bearing age (farms),)
# Keeping 2741/2781 (98.6%) features
# (2741, 6)
# Filtering item310197 (Persimmons, Harvested (farms), 1992)
# Keeping 2738/2781 (98.5%) features
# (2738, 6)
# Filtering item310119 (Kiwifruit, Total (acres), 1992)
# Keeping 2733/2781 (98.3%) features
# (2733, 6)
# Filtering item310101 (Grapes (see text) (fresh wt), Total (acres), 1992)
# Keeping 2733/2781 (98.3%) features
# (2733, 6)
# Filtering item310365 (English walnuts (in shell), Trees or vines not of bearing age(number), 1992)
# Keeping 2732/2781 (98.2%) features
# (2732, 6)
# Filtering item130207 (Land in orchards-500.0 acres or more, 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item100012 (Sprays, dusts, granules, fumigants, etc., to control--diseasesin crops & orchards (acres on which used), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item300002 (Land in orchards, Total (acres), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item010114 (Land in orchards (acres), 1992)
# Keeping 2741/2781 (98.6%) features
# (2741, 6)
# Filtering item110008 (Full owners-harvested crop land (acres), 1992)
# Keeping 2731/2781 (98.2%) features
# (2731, 6)
# Filtering item120282 (Land in orchards, (acres), 1992)
# Keeping 2731/2781 (98.2%) features
# (2731, 6)
# Filtering item300004 (Land in orchards, Irrigated (acres), 1992)
# Keeping 2731/2781 (98.2%) features
# (2731, 6)
# Filtering item130201 (Land in orchards-Irrigated, (acres), 1992)
# Keeping 2731/2781 (98.2%) features
# (2731, 6)
# Filtering item120071 (Agricultural chemicals ($1,000), 1992)
# Keeping 2720/2781 (97.8%) features
# (2720, 6)
# Filtering item100010 (Sprays, dusts, granules, fumigants, etc., to control--nematodesin crops (acres on which used), 1992)
# Keeping 2720/2781 (97.8%) features
# (2720, 6)
# Filtering item330010 (Floriculture Crops--Bedding, Foliage, Potted Flowering Plants andCut Flowers, Total, Square feet under glass or other protection, 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item320049 (Strawberries, Irrigated (farms), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item330017 (Cut flowers & cut florist greens, Farms, 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item330012 (Floriculture Crops--Bedding, Foliage, Potted Flowering Plants andCut Flowers, Total, Sales ($1,000), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item290032 (Broccoli, Irrigated (acres), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item290072 (Chinese peas, Irrigated (acres), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item120177 (SIC-Vegetables & melons (016), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item040006 (Farms with net gains, average per farm (dollars), 1992)
# Keeping 2742/2781 (98.6%) features
# (2742, 6)
# Filtering item290118 (Lettuce & Romaine, Harvested (acres), 1992)
# Keeping 2741/2781 (98.6%) features
# (2741, 6)
# Filtering item290060 (Cauliflower, Irrigated (acres), 1992)
# Keeping 2741/2781 (98.6%) features
# (2741, 6)
# Filtering item270078 (Peanuts for nuts, Harvested (pounds), 1992)
# Keeping 2746/2781 (98.7%) features
# (2746, 6)
# Filtering item270080 (Peanuts for nuts, Irrigated (acres), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item290204 (Watermelons, Irrigated (acres), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item270079 (Peanuts for nuts, Irrigated (farms), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item060059 (Crop land idle, (acres), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item020045 (Other grains, ($1,000), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item260102 (Rye for grain, Harvested (acres), 1992)
# Keeping 2743/2781 (98.6%) features
# (2743, 6)
# Filtering item310104 (Grapes (see text) (fresh weight) -- Trees or vines not of bearingage (number), 1992)
# Keeping 2743/2781 (98.6%) features
# (2743, 6)
# Filtering item040014 (Gov payments-CRP & WRP, ($1,000), 1992)
# Keeping 2738/2781 (98.5%) features
# (2738, 6)
# Filtering item010105 (Peanuts for nuts (farms), 1992)
# Keeping 2738/2781 (98.5%) features
# (2738, 6)
# Filtering item050037 (Farms with 10 workers or more - Less than 150 days (workers), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item310144 (Nectarines, Harvested (pounds), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item120099 (Farms with net losses, ($1,000), 1992)
# Keeping 2744/2781 (98.7%) features
# (2744, 6)
# Filtering item310005 (Apples, Trees or vines not of bearing age (number), 1992)
# Keeping 2743/2781 (98.6%) features
# (2743, 6)
# Filtering item310053 (Sweet cherries, Harvested (farms), 1992)
# Keeping 2740/2781 (98.5%) features
# (2740, 6)
# Filtering item310189 (Pears, Harvested (pounds), 1992)
# Keeping 2740/2781 (98.5%) features
# (2740, 6)
# Filtering item100015 (Chemicals used for defoliation or for growth control of cropsor thinning of fruit (farms), 1992)
# Keeping 2740/2781 (98.5%) features
# (2740, 6)
# Filtering item050046 (Reported both - workers working 150 days or more & workersworking less than 150 days (less than 150 days), 1992)
# Keeping 2739/2781 (98.5%) features
# (2739, 6)
# Filtering item310183 (Pears, Total (trees or vines), 1992)
# Keeping 2739/2781 (98.5%) features
# (2739, 6)
# Filtering item310010 (Apricots, Total (farms), 1992)
# Keeping 2735/2781 (98.3%) features
# (2735, 6)
# Filtering item010070 (Barley for grain (acres), 1992)
# Keeping 2744/2781 (98.7%) features
# (2744, 6)
# Filtering item120016 (Corn for grain, (farms), 1992)
# Keeping 2729/2781 (98.1%) features
# (2729, 6)
# Filtering item120014 (Grains, (farms), 1992)
# Keeping 2701/2781 (97.1%) features
# (2701, 6)
# Filtering item110056 (Corporation-Family held, (acres), 1992)
# Keeping 2701/2781 (97.1%) features
# (2701, 6)
# Filtering item020041 (Barley, ($1,000), 1992)
# Keeping 2701/2781 (97.1%) features
# (2701, 6)
# Filtering item040009 (Farms with net losses, average per farm (dollars), 1992)
# Keeping 2701/2781 (97.1%) features
# (2701, 6)
# Filtering item120227 (Corn for grain or seed, (bu.), 1992)
# Keeping 2698/2781 (97.0%) features
# (2698, 6)
# Filtering item060045 (Total crop land, (acres), 1992)
# Keeping 2694/2781 (96.9%) features
# (2694, 6)
# Filtering item110055 (Corporation-Family held, (farms), 1992)
# Keeping 2693/2781 (96.8%) features
# (2693, 6)
# Filtering item130109 (Soybeans for beans, (acres), 1992)
# Keeping 2675/2781 (96.2%) features
# (2675, 6)
# Filtering item030002 (Total farm production exp, ($1,000), 1992)
# Keeping 2723/2781 (97.9%) features
# (2723, 6)
# Filtering item030015 (Agricultural chemicals, ($1,000), 1992)
# Keeping 2711/2781 (97.5%) features
# (2711, 6)
# Filtering item120037 (Vegetables, sweet corn, & melons($1,000), 1992)
# Keeping 2711/2781 (97.5%) features
# (2711, 6)
# Filtering item100012 (Sprays, dusts, granules, fumigants, etc., to control--diseasesin crops & orchards (acres on which used), 1992)
# Keeping 2711/2781 (97.5%) features
# (2711, 6)
# Filtering item350005 (Black & other races, Market value of agricultural products sold($1,000), 1992)
# Keeping 2711/2781 (97.5%) features
# (2711, 6)
# Filtering item050045 (Reported both - workers working 150 days or more & workersworking less than 150 days (150 days or more), 1992)
# Keeping 2707/2781 (97.3%) features
# (2707, 6)
# Filtering item330048 (Vegetable & flower seeds, Sales ($1,000), 1992)
# Keeping 2707/2781 (97.3%) features
# (2707, 6)
# Filtering item120079 (Contract labor ($1,000), 1992)
# Keeping 2707/2781 (97.3%) features
# (2707, 6)
# Filtering item050040 (Reported only workers working 150 days or more ($1,000 payroll), 1992)
# Keeping 2706/2781 (97.3%) features
# (2706, 6)
# Filtering item120100 (Farms with losses average per farm, (dollars), 1992)
# Keeping 2706/2781 (97.3%) features
# (2706, 6)
# Filtering item040010 (Gov payments-Total received, (farms), 1992)
# Keeping 2721/2781 (97.8%) features
# (2721, 6)
# Filtering item120089 (Property taxes ($1,000), 1992)
# Keeping 2720/2781 (97.8%) features
# (2720, 6)
# Filtering item130133 (Irish potatoes-0.1 to 4.9 acres, 1992)
# Keeping 2720/2781 (97.8%) features
# (2720, 6)
# Filtering item130141 (Sugar beets for sugar, (tons), 1992)
# Keeping 2715/2781 (97.6%) features
# (2715, 6)
# Filtering item130148 (Sugar beets for sugar-500 acres or more, 1992)
# Keeping 2715/2781 (97.6%) features
# (2715, 6)
# Filtering item260028 (Other spring wheat for grain, Harvested (bu), 1992)
# Keeping 2713/2781 (97.6%) features
# (2713, 6)
# Filtering item130147 (Sugar beets for sugar-250 to 499 acres, 1992)
# Keeping 2713/2781 (97.6%) features
# (2713, 6)
# Filtering item260073 (Flaxseed, Harvested (bu.), 1992)
# Keeping 2711/2781 (97.5%) features
# (2711, 6)
# Filtering item110008 (Full owners-harvested crop land (acres), 1992)
# Keeping 2709/2781 (97.4%) features
# (2709, 6)
# Filtering item130119 (Dry edible beans excluding dry limas (acres), 1992)
# Keeping 2706/2781 (97.3%) features
# (2706, 6)
# Filtering item350005 (Black & other races, Market value of agricultural products sold($1,000), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item030011 (Seeds, bulbs, plants & trees, ($1,000), 1992)
# Keeping 2737/2781 (98.4%) features
# (2737, 6)
# Filtering item120037 (Vegetables, sweet corn, & melons($1,000), 1992)
# Keeping 2737/2781 (98.4%) features
# (2737, 6)
# Filtering item100010 (Sprays, dusts, granules, fumigants, etc., to control--nematodesin crops (acres on which used), 1992)
# Keeping 2737/2781 (98.4%) features
# (2737, 6)
# Filtering item020053 (Vegetables, sweet corn, & melons ($1,000), 1992)
# Keeping 2737/2781 (98.4%) features
# (2737, 6)
# Filtering item290206 (Other vegetables, Harvested (acres), 1992)
# Keeping 2737/2781 (98.4%) features
# (2737, 6)
# Filtering item290207 (Other vegetables, Irrigated (farms), 1992)
# Keeping 2736/2781 (98.4%) features
# (2736, 6)
# Filtering item120039 (Fruits, nuts, & berries, ($1,000), 1992)
# Keeping 2736/2781 (98.4%) features
# (2736, 6)
# Filtering item290031 (Broccoli, Irrigated (farms), 1992)
# Keeping 2735/2781 (98.3%) features
# (2735, 6)
# Filtering item120079 (Contract labor ($1,000), 1992)
# Keeping 2735/2781 (98.3%) features
# (2735, 6)
# Filtering item290103 (Garlic, Irrigated (farms), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item010057 (Corn for grain or seed (farms), 1992)
# Keeping 2734/2781 (98.3%) features
# (2734, 6)
# Filtering item310377 (Other nuts (in shell), Harvested (farms), 1992)
# Keeping 2731/2781 (98.2%) features
# (2731, 6)
# Filtering item060065 (Woodland not pastured, (acres), 1992)
# Keeping 2731/2781 (98.2%) features
# (2731, 6)
# Filtering item120202 (Calves, (number), 1992)
# Keeping 2727/2781 (98.1%) features
# (2727, 6)
# Filtering item120017 (Corn for grain ($1,000), 1992)
# Keeping 2724/2781 (98.0%) features
# (2724, 6)
# Filtering item280157 (Corn for silage or green chop, Harvested(acres), 1992)
# Keeping 2722/2781 (97.9%) features
# (2722, 6)
# Filtering item140052 (Heifers & heifer calves, (number), 1992)
# Keeping 2703/2781 (97.2%) features
# (2703, 6)
# Filtering item120115 (Farms by size-260 to 499 acres, 1992)
# Keeping 2664/2781 (95.8%) features
# (2664, 6)
# Filtering item110054 (Partnership, (acres), 1992)
# Keeping 2664/2781 (95.8%) features
# (2664, 6)
# Filtering item260098 (Rice, Harvested (cwt), 1992)
# Keeping 2739/2781 (98.5%) features
# (2739, 6)
# Filtering item050017 (Farms with 1 worker - 150 days or more (workers), 1992)
# Keeping 2736/2781 (98.4%) features
# (2736, 6)
# Filtering item030021 (Diesel fuel, ($1,000), 1992)
# Keeping 2701/2781 (97.1%) features
# (2701, 6)
# Filtering item130071 (Rice-25 to 99 acres, 1992)
# Keeping 2697/2781 (97.0%) features
# (2697, 6)
# Filtering item120089 (Property taxes ($1,000), 1992)
# Keeping 2696/2781 (96.9%) features
# (2696, 6)
# Filtering item020045 (Other grains, ($1,000), 1992)
# Keeping 2696/2781 (96.9%) features
# (2696, 6)
# Filtering item270015 (Soybeans for beans, Irrigated (acres), 1992)
# Keeping 2695/2781 (96.9%) features
# (2695, 6)
# Filtering item070022 (Harvested crop land by size of farm: 500-999 acres (acresharvested), 1992)
# Keeping 2676/2781 (96.2%) features
# (2676, 6)
# Filtering item130072 (Rice-100 to 249 acres, 1992)
# Keeping 2675/2781 (96.2%) features
# (2675, 6)
# Filtering item040045 (CCC Loan-Peanuts, rye, rice, tobacco, & honey ($1,000), 1992)
# Keeping 2675/2781 (96.2%) features
# (2675, 6)
# Filtering item260099 (Rice, Irrigated (farms), 1992)
# Keeping 2739/2781 (98.5%) features
# (2739, 6)
# Filtering item130117 (Soybeans for beans-500 acres or more, 1992)
# Keeping 2739/2781 (98.5%) features
# (2739, 6)
# Filtering item130073 (Rice-250 to 499 acres, 1992)
# Keeping 2734/2781 (98.3%) features
# (2734, 6)
# Filtering item070014 (Harvested crop land by size of farm: 140-179 acres (acres harvested), 1992)
# Keeping 2721/2781 (97.8%) features
# (2721, 6)
# Filtering item120233 (Sorghum for grain or seed, (bu.), 1992)
# Keeping 2719/2781 (97.8%) features
# (2719, 6)
# Filtering item100008 (Sprays, dusts, granules, fumigants, etc., to control--insectson hay & other crops (acres on which used), 1992)
# Keeping 2716/2781 (97.7%) features
# (2716, 6)
# Filtering item040045 (CCC Loan-Peanuts, rye, rice, tobacco, & honey ($1,000), 1992)
# Keeping 2716/2781 (97.7%) features
# (2716, 6)
# Filtering item130040 (Wheat for grain-1 to 24 acres, 1992)
# Keeping 2716/2781 (97.7%) features
# (2716, 6)
# Filtering item280129 (Hay-alfalfa, other tame, small grain, wild, grass silage, greenchop, etc. (see text), irrigated (farms), 1992)
# Keeping 2715/2781 (97.6%) features
# (2715, 6)
# Filtering item110046 (Operators by age group-Average age, 1992)
# Keeping 2715/2781 (97.6%) features
# (2715, 6)
# Filtering item310005 (Apples, Trees or vines not of bearing age (number), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item130207 (Land in orchards-500.0 acres or more, 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item310104 (Grapes (see text) (fresh weight) -- Trees or vines not of bearingage (number), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item310002 (Apples, Total (acres), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item120282 (Land in orchards, (acres), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item310003 (Apples, Total (trees or vines), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# ...
# (2719, 6)
# Filtering item040008 (Farms with net losses, ($1,000), 1992)
# Keeping 2719/2781 (97.8%) features
# (2719, 6)
# Filtering item080031 (Irrigated acres by size of farm: 260-499 acres, (acres irrigated), 1992)
# Keeping 2719/2781 (97.8%) features
# (2719, 6)
# Filtering item060004 (Estimated market value of land & buildings (farms), 1992)
# Keeping 2619/2781 (94.2%) features
# (2619, 6)
# Filtering item080026 (Irrigated acres by size of farm: 180-219 acres, (farms), 1992)
# Keeping 2619/2781 (94.2%) features
# (2619, 6)
# Filtering item050031 (Farms with 2 workers - Less than 150 days (workers), 1992)
# Keeping 2618/2781 (94.1%) features
# (2618, 6)
# Filtering item130205 (Land in orchards-100.0 to 249.9 acres, 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item130206 (Land in orchards-250.0 to 499.9 acres, 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item120282 (Land in orchards, (acres), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item310002 (Apples, Total (acres), 1992)
# Keeping 2746/2781 (98.7%) features
# (2746, 6)
# Filtering item310009 (Apples, Harvested (pounds), 1992)
# Keeping 2746/2781 (98.7%) features
# (2746, 6)
# Filtering item310005 (Apples, Trees or vines not of bearing age (number), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item130041 (Wheat for grain-25 to 99 acres, 1992)
# Keeping 2735/2781 (98.3%) features
# (2735, 6)
# Filtering item310008 (Apples, Harvested (farms), 1992)
# Keeping 2734/2781 (98.3%) features
# (2734, 6)
# Filtering item090044 (Manufactured in the last five years--Pickup balers, (numbers), 1992)
# Keeping 2733/2781 (98.3%) features
# (2733, 6)
# Filtering item120205 (Cattle fattened on grain & conc (farms), 1992)
# Keeping 2731/2781 (98.2%) features
# (2731, 6)
# Filtering item120069 (Commercial fertilizer ($1,000), 1992)
# Keeping 2738/2781 (98.5%) features
# (2738, 6)
# Filtering item290054 (Carrots, Harvested (acres), 1992)
# Keeping 2738/2781 (98.5%) features
# (2738, 6)
# Filtering item340017 (Ginseng (see text), Harvested (acres), 1992)
# Keeping 2737/2781 (98.4%) features
# (2737, 6)
# Filtering item130180 (Hay-alfalfa, other tame, small grain, wild, grass silage, greenchop, etc. (see text), (tons, dry), 1992)
# Keeping 2729/2781 (98.1%) features
# (2729, 6)
# Filtering item100010 (Sprays, dusts, granules, fumigants, etc., to control--nematodesin crops (acres on which used), 1992)
# Keeping 2729/2781 (98.1%) features
# (2729, 6)
# Filtering item290204 (Watermelons, Irrigated (acres), 1992)
# Keeping 2729/2781 (98.1%) features
# (2729, 6)
# Filtering item070024 (Harvested crop land by size of farm: 1,000-1,999 ac (acresharvested), 1992)
# Keeping 2708/2781 (97.4%) features
# (2708, 6)
# Filtering item040018 (Gross before taxes & expenses avg/farm (dollars), 1992)
# Keeping 2708/2781 (97.4%) features
# (2708, 6)
# Filtering item290053 (Carrots, Harvested (farms), 1992)
# Keeping 2708/2781 (97.4%) features
# (2708, 6)
# Filtering item340018 (Ginseng (see text), Harvested (pounds), 1992)
# Keeping 2708/2781 (97.4%) features
# (2708, 6)
# Filtering item120277 (Hay-alfalfa, other tame, small grain, wild, grass silage, greenchop, etc. (see text), (acres), 1992)
# Keeping 2740/2781 (98.5%) features
# (2740, 6)
# Filtering item130187 (Hay-alfalfa, other tame, small grain, wild, grass silage, greenchop, etc. (see text), 500 acres or more, 1992)
# Keeping 2740/2781 (98.5%) features
# (2740, 6)
# Filtering item280130 (Hay-alfalfa, other tame, small grain, wild, grass silage, greenchop, etc., irrigated (acres), 1992)
# Keeping 2739/2781 (98.5%) features
# (2739, 6)
# Filtering item280133 (Alfalfa hay, Harvested (tons, dry), 1992)
# Keeping 2737/2781 (98.4%) features
# (2737, 6)
# Filtering item120035 (Hay, silage, & field seeds, ($1,000), 1992)
# Keeping 2737/2781 (98.4%) features
# (2737, 6)
# Filtering item130196 (Vegetables harvested for sale-250.0 to 499.9 acres, 1992)
# Keeping 2737/2781 (98.4%) features
# (2737, 6)
# Filtering item290030 (Broccoli, Harvested (acres), 1992)
# Keeping 2737/2781 (98.4%) features
# (2737, 6)
# Filtering item130188 (Vegetables harvested for sale (see text) (farms), 1992)
# Keeping 2732/2781 (98.2%) features
# (2732, 6)
# Filtering item120010 (Total sales (see text), ($1,000), 1992)
# Keeping 2704/2781 (97.2%) features
# (2704, 6)
# Filtering item290117 (Lettuce & Romaine, Harvested (farms), 1992)
# Keeping 2702/2781 (97.2%) features
# (2702, 6)
# Filtering item140109 (Calves sold, 20-49 (farms), 1992)
# Keeping 2731/2781 (98.2%) features
# (2731, 6)
# Filtering item110006 (Full owners, (acres), 1992)
# Keeping 2730/2781 (98.2%) features
# (2730, 6)
# Filtering item010106 (Peanuts for nuts (acres), 1992)
# Keeping 2729/2781 (98.1%) features
# (2729, 6)
# Filtering item120192 (Beef cows, (number), 1992)
# Keeping 2729/2781 (98.1%) features
# (2729, 6)
# Filtering item010105 (Peanuts for nuts (farms), 1992)
# Keeping 2729/2781 (98.1%) features
# (2729, 6)
# Filtering item270080 (Peanuts for nuts, Irrigated (acres), 1992)
# Keeping 2728/2781 (98.1%) features
# (2728, 6)
# Filtering item140034 (Beef cows inventory 500 or more, (number), 1992)
# Keeping 2728/2781 (98.1%) features
# (2728, 6)
# Filtering item280138 (Small grain hay, Harvested (tons, dry), 1992)
# Keeping 2727/2781 (98.1%) features
# (2727, 6)
# Filtering item290202 (Watermelons, Harvested (acres), 1992)
# Keeping 2726/2781 (98.0%) features
# (2726, 6)
# Filtering item130143 (Sugar beets for sugar-Irrigated (acres), 1992)
# Keeping 2726/2781 (98.0%) features
# (2726, 6)
# Filtering item130197 (Vegetables harvested for sale-500.0 acres or more, 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item120280 (Vegetables harvested for sale (see text) (acres), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item290022 (Snap beans, Harvested (acres), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item290002 (Land used for veg (see text), Harvested (acres), 1992)
# Keeping 2743/2781 (98.6%) features
# (2743, 6)
# Filtering item290118 (Lettuce & Romaine, Harvested (acres), 1992)
# Keeping 2742/2781 (98.6%) features
# (2742, 6)
# Filtering item130196 (Vegetables harvested for sale-250.0 to 499.9 acres, 1992)
# Keeping 2742/2781 (98.6%) features
# (2742, 6)
# Filtering item130004 (Harvested crop land-Irrigated, (acres), 1992)
# Keeping 2741/2781 (98.6%) features
# (2741, 6)
# Filtering item080006 (Other crop land excluding crop land pastured (acres), 1992)
# Keeping 2740/2781 (98.5%) features
# (2740, 6)
# Filtering item320004 (Berries, Irrigated (farms), 1992)
# Keeping 2739/2781 (98.5%) features
# (2739, 6)
# Filtering item120106 (Government payments-CRP & WRP Average per farm (dollars), 1992)
# Keeping 2738/2781 (98.5%) features
# (2738, 6)
# Filtering item290002 (Land used for veg (see text), Harvested (acres), 1992)
# Keeping 2744/2781 (98.7%) features
# (2744, 6)
# Filtering item030021 (Diesel fuel, ($1,000), 1992)
# Keeping 2709/2781 (97.4%) features
# (2709, 6)
# Filtering item020047 (Cotton & cottonseed, ($1,000), 1992)
# Keeping 2699/2781 (97.1%) features
# (2699, 6)
# Filtering item040041 (CCC Loan-Cotton,($1,000), 1992)
# Keeping 2699/2781 (97.1%) features
# (2699, 6)
# Filtering item100008 (Sprays, dusts, granules, fumigants, etc., to control--insectson hay & other crops (acres on which used), 1992)
# Keeping 2699/2781 (97.1%) features
# (2699, 6)
# Filtering item290120 (Lettuce & Romaine, Irrigated (acres), 1992)
# Keeping 2699/2781 (97.1%) features
# (2699, 6)
# Filtering item100016 (Chemicals used for defoliation or for growth control of cropsor thinning of fruit (acres on which used), 1992)
# Keeping 2699/2781 (97.1%) features
# (2699, 6)
# Filtering item010034 (Net cash return from agricultural sales for the farm unit (seetext), average per farm (dollars), 1992)
# Keeping 2696/2781 (96.9%) features
# (2696, 6)
# Filtering item070042 (Harvested crop land by acres harvested: 500-999 acres (acres), 1992)
# Keeping 2684/2781 (96.5%) features
# (2684, 6)
# Filtering item140037 (Milk cows inventory 1-9, (farms), 1992)
# Keeping 2684/2781 (96.5%) features
# (2684, 6)
# Filtering item140020 (Beef cows inventory, (number), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item060069 (Pastureland & rangeland other than crop land & woodlandpastured, (acres), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item060068 (Pastureland & rangeland other than crop land & woodlandpastured, (farms), 1992)
# Keeping 2743/2781 (98.6%) features
# (2743, 6)
# Filtering item140138 (Cattle fattened on grain & concentrates sold ($1,000), 1992)
# Keeping 2742/2781 (98.6%) features
# (2742, 6)
# Filtering item080012 (Pastureland & other land (farms), 1992)
# Keeping 2742/2781 (98.6%) features
# (2742, 6)
# Filtering item100006 (Pastureland & rangeland fertilized (acres used), 1992)
# Keeping 2741/2781 (98.6%) features
# (2741, 6)
# Filtering item110006 (Full owners, (acres), 1992)
# Keeping 2740/2781 (98.5%) features
# (2740, 6)
# Filtering item140104 (Calves sold, ($1,000), 1992)
# Keeping 2737/2781 (98.4%) features
# (2737, 6)
# Filtering item140112 (Calves sold, 50-99 (number), 1992)
# Keeping 2736/2781 (98.4%) features
# (2736, 6)
# Filtering item020084 (SIC-Beef cattle, except feedlots (0212), 1992)
# Keeping 2734/2781 (98.3%) features
# (2734, 6)
# Filtering item350004 (Black & other races, Harvested crop land (acres), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item350008 (Black & other races, Farms by value of sales, occupation farming($10,000 or more), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item110058 (Corporation-Other than family held (acres), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item130107 (Tobacco-50.0 acres or more, 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item370010 (Asian/Pacific Islander, All farms (land in farms), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item370012 (Asian or Pacific Islander, Farms with sales of $10,000 or more(land in farms), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item380002 (Spanish origin, All farms (land in farms), 1992)
# Keeping 2746/2781 (98.7%) features
# (2746, 6)
# Filtering item120171 (Other-cooperative, estate or trust, institutional, etc. (acres), 1992)
# Keeping 2746/2781 (98.7%) features
# (2746, 6)
# Filtering item360006 (Black & other races, Part Owners (harvested crop land), 1992)
# Keeping 2746/2781 (98.7%) features
# (2746, 6)
# Filtering item050046 (Reported both - workers working 150 days or more & workersworking less than 150 days (less than 150 days), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item270012 (Soybeans for beans, Harvested(acres), 1992)
# Keeping 2737/2781 (98.4%) features
# (2737, 6)
# Filtering item040034 (CCC Loan-Wheat, (farms), 1992)
# Keeping 2737/2781 (98.4%) features
# (2737, 6)
# Filtering item130192 (Vegetables harvested for sale-0.1 to 4.9 acres, 1992)
# Keeping 2732/2781 (98.2%) features
# (2732, 6)
# Filtering item060053 (Crop land in cover crops, legumes, & soil-improvement grasses,not harvested & not pastured, (acres), 1992)
# Keeping 2732/2781 (98.2%) features
# (2732, 6)
# Filtering item070023 (Harvested crop land by size of farm: 1,000-1,999 acres (farms), 1992)
# Keeping 2726/2781 (98.0%) features
# (2726, 6)
# Filtering item040030 (CCC Loan-Total (farms), 1992)
# Keeping 2718/2781 (97.7%) features
# (2718, 6)
# Filtering item050012 (Farms with-10 workers or more, (farms), 1992)
# Keeping 2715/2781 (97.6%) features
# (2715, 6)
# Filtering item260007 (Sorghum for grain or seed, Harvested(acres), 1992)
# Keeping 2713/2781 (97.6%) features
# (2713, 6)
# Filtering item280001 (Field seed & grass seed crops, Harvested(farms), 1992)
# Keeping 2713/2781 (97.6%) features
# (2713, 6)
# Filtering item120104 (Government payments-CRP & WRP (farms), 1992)
# Keeping 2708/2781 (97.4%) features
# (2708, 6)
# Filtering item010111 (Vegetables harvested for sale (see text) (farms), 1992)
# Keeping 2747/2781 (98.8%) features
# (2747, 6)
# Filtering item010089 (Soybeans for beans (bu.), 1992)
# Keeping 2729/2781 (98.1%) features
# (2729, 6)
# Filtering item130040 (Wheat for grain-1 to 24 acres, 1992)
# Keeping 2729/2781 (98.1%) features
# (2729, 6)
# Filtering item110014 (Part owners-harvested crop land (acres), 1992)
# Keeping 2695/2781 (96.9%) features
# (2695, 6)
# Filtering item130035 (Wheat for grain, (farms), 1992)
# Keeping 2682/2781 (96.4%) features
# (2682, 6)
# Filtering item260005 (Corn for grain or seed, Irrigated (acres), 1992)
# Keeping 2682/2781 (96.4%) features
# (2682, 6)
# Filtering item120021 (Soybeans, ($1,000), 1992)
# Keeping 2682/2781 (96.4%) features
# (2682, 6)
# Filtering item010018 (Irrigated land (acres), 1992)
# Keeping 2678/2781 (96.3%) features
# (2678, 6)
# Filtering item290023 (Snap beans, Irrigated (farms), 1992)
# Keeping 2678/2781 (96.3%) features
# (2678, 6)
# Filtering item290158 (Pumpkins, Harvested (acres), 1992)
# Keeping 2677/2781 (96.3%) features
# (2677, 6)
# Filtering item130206 (Land in orchards-250.0 to 499.9 acres, 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item080019 (Irrigated acres by size of farm: 50-69 acres, (acres irrigated), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item050013 (Farms with-10 workers or more, (workers), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item130205 (Land in orchards-100.0 to 249.9 acres, 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item080018 (Irrigated acres by size of farm: 50-69 acres, (farms), 1992)
# Keeping 2745/2781 (98.7%) features
# (2745, 6)
# Filtering item030043 (Cash rent, ($1,000), 1992)
# Keeping 2734/2781 (98.3%) features
# (2734, 6)
# Filtering item120067 (Seeds, bulbs, plants, & trees ($1,000), 1992)
# Keeping 2727/2781 (98.1%) features
# (2727, 6)
# Filtering item040018 (Gross before taxes & expenses avg/farm (dollars), 1992)
# Keeping 2727/2781 (98.1%) features
# (2727, 6)
# Filtering item130204 (Land in orchards-25.0 to 99.9 acres, 1992)
# Keeping 2727/2781 (98.1%) features
# (2727, 6)
# Filtering item020055 (Fruits, nuts, & berries, ($1,000), 1992)
# Keeping 2727/2781 (98.1%) features
# (2727, 6)
# Filtering item290022 (Snap beans, Harvested (acres), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item290042 (Head cabbage, Harvested (acres), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item130196 (Vegetables harvested for sale-250.0 to 499.9 acres, 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item290142 (Green peas, excluding green cowpeas, Harvested(acres), 1992)
# Keeping 2748/2781 (98.8%) features
# (2748, 6)
# Filtering item020009 (Value of sales $2,500-$4,999 ($1,000), 1992)
# Keeping 2723/2781 (97.9%) features
# (2723, 6)
# Filtering item120280 (Vegetables harvested for sale (see text) (acres), 1992)
# Keeping 2722/2781 (97.9%) features
# (2722, 6)
# Filtering item120019 (Wheat, ($1,000), 1992)
# Keeping 2722/2781 (97.9%) features
# (2722, 6)
# Filtering item050010 (Farms with-5 to 9 workers, (farms), 1992)
# Keeping 2720/2781 (97.8%) features
# (2720, 6)
# Filtering item240006 (Geese, Inventory (number), 1992)
# Keeping 2719/2781 (97.8%) features
# (2719, 6)
# Filtering item120110 (Farms by size-70 to 99 acres, 1992)
# Keeping 2717/2781 (97.7%) features
# (2717, 6)
# Filtering item120102 (Government payments-Tot received($1,000), 1992)
# Keeping 2731/2781 (98.2%) features
# (2731, 6)
# Filtering item130092 (Cotton-100 to 249 acres, 1992)
# Keeping 2724/2781 (98.0%) features
# (2724, 6)
# Filtering item110018 (Tenants-harvested crop land (acres), 1992)
# Keeping 2720/2781 (97.8%) features
# (2720, 6)
# Filtering item090038 (Manufactured in the last five years--Grain & bean combines,(numbers), 1992)
# Keeping 2719/2781 (97.8%) features
# (2719, 6)
# Filtering item100008 (Sprays, dusts, granules, fumigants, etc., to control--insectson hay & other crops (acres on which used), 1992)
# Keeping 2716/2781 (97.7%) features
# (2716, 6)
# Filtering item060065 (Woodland not pastured, (acres), 1992)
# Keeping 2716/2781 (97.7%) features
# (2716, 6)
# Filtering item270004 (Cotton, Irrigated (farms), 1992)
# Keeping 2715/2781 (97.6%) features
# (2715, 6)
# Filtering item090023 (Cotton pickers & strippers, (farms), 1992)
# Keeping 2711/2781 (97.5%) features
# (2711, 6)
# Filtering item120146 (Operators days work off farm 150-199 days, 1992)
# Keeping 2709/2781 (97.4%) features
# (2709, 6)
# Filtering item090022 (Grain & bean combines, (number), 1992)
# Keeping 2697/2781 (97.0%) features
# (2697, 6)

# %%
feat_importance_df = pd.read_csv(result_path, index_col=0)
feat_importance_df[importance_col] = pd.to_numeric(
    feat_importance_df[importance_col])

feat_importance_df.sort_values(importance_col, ascending=False, inplace=True)
# display(feat_importance_df)
# feat_importance_df = feat_importance_df.iloc[:top_n]

# %%
corr_df
# Out:
#             item010001  item010002  item010003  item010004  item010005  \
# item010001    1.000000    0.506992    0.067692    0.057044    0.232677
# item010002    0.506992    1.000000    0.745195    0.491535    0.419074
# item010003    0.067692    0.745195    1.000000    0.627445    0.594970
# item010004    0.057044    0.491535    0.627445    1.000000    0.074078
# item010005    0.232677    0.419074    0.594970    0.074078    1.000000
# ...                ...         ...         ...         ...         ...
# item390008    0.026215    0.522425    0.537352    0.401581    0.430171
# item390009    0.073097    0.312889    0.236244    0.158127    0.243300
# item390010    0.140846    0.396688    0.278156    0.201955    0.261330
# item390011    0.142345    0.282739    0.150431    0.054779    0.221921
# item390012    0.297861    0.547599    0.329562    0.134198    0.363355
#
#             item010006  item010007  item010008  item010009  item010010  ...  \
# item010001    0.130027    0.790803    0.806179    0.888833    0.892464  ...
# item010002    0.494597    0.282242    0.106796    0.192387    0.477400  ...
# item010003    0.568417    0.214001    0.406558    0.339459    0.021926  ...
# item010004    0.634216    0.089109    0.152392    0.319675    0.137044  ...
# item010005    0.038717    0.488694    0.550609    0.361861    0.106338  ...
# ...                ...         ...         ...         ...         ...  ...
# item390008    0.153169    0.005191    0.146815    0.233309    0.134242  ...
# item390009    0.031915    0.087518    0.049626    0.011158    0.008434  ...
# item390010    0.019690    0.158470    0.081698    0.008714    0.023732  ...
# item390011    0.012022    0.109884    0.062566    0.053964    0.082748  ...
# item390012    0.025986    0.204967    0.109289    0.125323    0.210526  ...
#
#             item390003  item390004  item390005  item390006  item390007  \
# item010001    0.320337    0.268546    0.211981    0.126347    0.035885
# item010002    0.368619    0.367217    0.402080    0.456940    0.477673
# item010003    0.128479    0.187950    0.261923    0.388783    0.455800
# item010004    0.040739    0.039858    0.116240    0.208774    0.290147
# item010005    0.179054    0.236409    0.279876    0.359949    0.398051
# ...                ...         ...         ...         ...         ...
# item390008    0.484029    0.487524    0.538949    0.651441    0.738502
# item390009    0.631174    0.616939    0.612035    0.615975    0.613048
# item390010    0.683461    0.636079    0.621797    0.634767    0.623742
# item390011    0.480652    0.437279    0.441958    0.423365    0.420079
# item390012    0.822749    0.789729    0.748362    0.735121    0.677441
#
#             item390008  item390009  item390010  item390011  item390012
# item010001    0.026215    0.073097    0.140846    0.142345    0.297861
# item010002    0.522425    0.312889    0.396688    0.282739    0.547599
# item010003    0.537352    0.236244    0.278156    0.150431    0.329562
# item010004    0.401581    0.158127    0.201955    0.054779    0.134198
# item010005    0.430171    0.243300    0.261330    0.221921    0.363355
# ...                ...         ...         ...         ...         ...
# item390008    1.000000    0.614985    0.639508    0.377380    0.648355
# item390009    0.614985    1.000000    0.712781    0.485458    0.605038
# item390010    0.639508    0.712781    1.000000    0.481370    0.680386
# item390011    0.377380    0.485458    0.481370    1.000000    0.488882
# item390012    0.648355    0.605038    0.680386    0.488882    1.000000
#
# [2781 rows x 2781 columns]
